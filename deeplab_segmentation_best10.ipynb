# %%
"""
README: DeepLabV3 Semantic Segmentation Per-Class, Per-City Best-10 Visualizer

This script:
- Runs inference on a directory of images with a trained DeepLabV3+MobileNetV3 segmentation model,
- Computes IoU (Intersection over Union) for each class, per city,
- Saves the best-10 (highest IoU) segmentation results per class/city as visualization sets:
    - original.jpg (original image)
    - mask.jpg     (ground truth mask overlay, always green)
    - prediction.jpg (predicted mask overlay, class-specific color)
- Output folders are organized by class and city for easy visual benchmarking.

How to use:
- Set the paths for your trained model, test images, and output directory below.
- Optionally, edit the class and city definitions as needed.
- Run the script; visual outputs will be created in OUTPUT_DIR.

Requirements:
- Python 3.8+
- torch
- torchvision
- opencv-python
- numpy
- tqdm

Author: Bahadir Akin Akgul
Date: 13.07.2025
"""

import os
import cv2
import torch
import numpy as np
from tqdm import tqdm
from pathlib import Path
from collections import defaultdict
import torchvision.transforms as T

# === SETTINGS ===
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
MODEL_PATH = "PATH_TO_TRAINED_MODEL/trained_model.pth"
DATA_DIR = "PATH_TO_TEST_IMAGES"
OUTPUT_DIR = Path("deeplab-best-10-segmented")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# Class IDs (model output indices)
CLASS_IDS = {
    'road': 1,
    'pedestrian': 2,
    'vehicle': 3
}

# Prediction colors (prediction.jpg only)
CLASS_COLORS = {
    1: (255, 0, 255),     # road - magenta
    2: (0, 255, 255),     # pedestrian - yellow
    3: (0, 0, 255)        # vehicle - red
}

MASK_COLOR = (0, 255, 0)  # green – for all mask.jpg

city_keywords = {
    'istanbul': ['libadiye', 'levent', 'taksim', 'ciragan', 'barbaros', 'dolmabahce', 'bagdat', 'muallim', 'katar'],
    'paris': ['paris-champs'],
    'munich': ['munih'],
    'marseille': ['marsilya']
}
city_translation = {
    'istanbul': 'Istanbul',
    'paris': 'Paris',
    'munich': 'Munich',
    'marseille': 'Marseille',
    'unknown': 'Unknown'
}

def get_city(filename):
    for city, keywords in city_keywords.items():
        if any(k in filename for k in keywords):
            return city
    return 'unknown'

def overlay_mask(image, mask, cls_id, color, alpha=0.5):
    overlay = image.copy()
    region = (mask == cls_id)
    color_layer = np.zeros_like(image, dtype=np.uint8)
    color_layer[region] = color
    return cv2.addWeighted(color_layer, alpha, overlay, 1 - alpha, 0)

# === LOAD MODEL ===
import torchvision.models.segmentation as models
model = models.deeplabv3_mobilenet_v3_large(weights=None, num_classes=4)
model.load_state_dict(torch.load(MODEL_PATH, map_location=DEVICE))
model.eval().to(DEVICE)

# === DATASET ===
image_files = sorted([f for f in os.listdir(DATA_DIR) if f.endswith(".jpg")])
transform = T.Compose([
    T.ToTensor(),
    T.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))
])

results_per_class = {k: defaultdict(list) for k in CLASS_IDS}

# === INFERENCE ===
print("Inference started...")
for fname in tqdm(image_files):
    name = os.path.splitext(fname)[0]
    img_path = os.path.join(DATA_DIR, fname)
    mask_path = os.path.join(DATA_DIR, name + "_mask.png")

    image = cv2.imread(img_path)
    if image is None:
        continue
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
    if mask is None or image.shape[:2] != mask.shape:
        continue

    input_tensor = transform(image).unsqueeze(0).to(DEVICE)
    with torch.no_grad():
        pred = model(input_tensor)['out'].squeeze().argmax(0).cpu().numpy()

    for label, cls_id in CLASS_IDS.items():
        pred_mask = (pred == cls_id).astype(np.uint8)
        gt_mask = (mask == cls_id).astype(np.uint8)

        inter = np.logical_and(pred_mask, gt_mask).sum()
        union = np.logical_or(pred_mask, gt_mask).sum()
        iou = inter / (union + 1e-6)

        if inter > 0:
            city = get_city(name)
            results_per_class[label][city].append({
                "iou": iou,
                "image": image.copy(),
                "gt": mask.copy(),
                "pred": pred.copy(),
                "name": name
            })

print("Inference completed.")

# === SAVE TOP 10 RESULTS ===
for label, cls_id in CLASS_IDS.items():
    for city, records in results_per_class[label].items():
        top10 = sorted(records, key=lambda x: -x['iou'])[:10]
        city_name = city_translation.get(city, city)
        save_dir = OUTPUT_DIR / label / city_name
        save_dir.mkdir(parents=True, exist_ok=True)

        for i, r in enumerate(top10, 1):
            name = f"{i:02d}_{r['name']}"
            dst = save_dir / name
            dst.mkdir(parents=True, exist_ok=True)

            img = r['image']
            gt_masked = overlay_mask(img, r['gt'], cls_id, MASK_COLOR)
            pred_masked = overlay_mask(img, r['pred'], cls_id, CLASS_COLORS[cls_id])

            cv2.imwrite(str(dst / "original.jpg"), img)
            cv2.imwrite(str(dst / "mask.jpg"), gt_masked)
            cv2.imwrite(str(dst / "prediction.jpg"), pred_masked)

            print(f"Saved: {label}/{city_name}/{name}")

print("All visualizations saved.")
# Out:
# 🔍 İnferencing başlıyor...
# 100%|██████████| 1316/1316 [02:22<00:00,  9.23it/s]
# ✅ İnferencing tamamlandı.
# 📂 Kaydedildi: road/Istanbul/01_muallimnaci-286_jpg.rf.0fdc57447155fcb982daae2e0539cd26
# 📂 Kaydedildi: road/Istanbul/02_bagdat-1-24_jpg.rf.72676e72054cf6522faf8369ba6bbced
# 📂 Kaydedildi: road/Istanbul/03_bagdat-1-342_jpg.rf.e377aa9fe6192b90ded430a02ee67c64
# 📂 Kaydedildi: road/Istanbul/04_bagdat-1-124_jpg.rf.96ffc5454f54898428232bfb72c8bdb4
# 📂 Kaydedildi: road/Istanbul/05_libadiye-318_jpg.rf.4a3330313065e0bced7acc55c066ec79
# 📂 Kaydedildi: road/Istanbul/06_bagdat-1-387_jpg.rf.e56c8ae432e48c6ad3ab1c8ec4879c61
# 📂 Kaydedildi: road/Istanbul/07_taksim-100_jpg.rf.be60ff28fe4d26482a6e2faebc740bfb
# 📂 Kaydedildi: road/Istanbul/08_bagdat-1-318_jpg.rf.beb44ee2457786f154172f6e2c5d0770
# 📂 Kaydedildi: road/Istanbul/09_muallimnaci-1038_jpg.rf.310083c7558ce84d0e315011a4e317b8
# 📂 Kaydedildi: road/Istanbul/10_libadiye-539_jpg.rf.72dd10809b7772d1a0a7df22e3bc90ef
# 📂 Kaydedildi: road/Marseille/01_marsilya2-564_jpg.rf.c5b3035f8b914bd589655a2ae9fdffb4
# 📂 Kaydedildi: road/Marseille/02_marsilya-1846_jpg.rf.25b5db748d153240c4f47bf857b0de03
# 📂 Kaydedildi: road/Marseille/03_marsilya2-166_jpg.rf.5212b68ae45f6fd7ec14eb68c3d1b788
# 📂 Kaydedildi: vehicle/Munich/10_munih-einstein-1460_jpg.rf.1dbf16d184b05ab3a00b5155548770d2
# 📂 Kaydedildi: vehicle/Paris/01_paris-champs-313_jpg.rf.9252bacd58f48e8bd00973ca7c5ea672
# 📂 Kaydedildi: vehicle/Paris/02_paris-champs-511_jpg.rf.7e5f52c73813906258ec9bfea0b86e50
# 📂 Kaydedildi: vehicle/Paris/03_paris-champs-53_jpg.rf.d5ef5c580a5039dcc5514d6afbd2c2bc
# 📂 Kaydedildi: vehicle/Paris/04_paris-champs-812_jpg.rf.d944b8fa029d7afbf5ceea6c32e3709c
# 📂 Kaydedildi: vehicle/Paris/05_paris-champs-500_jpg.rf.73174bc41fb463fb25e57776ad7d7d8f
# 📂 Kaydedildi: vehicle/Paris/06_paris-champs-1061_jpg.rf.05388c8f75a41e294add30756f298597
# 📂 Kaydedildi: vehicle/Paris/07_paris-champs-1118_jpg.rf.434048b6d6b7f4b4e5aabf9fa8a032fe
# 📂 Kaydedildi: vehicle/Paris/08_paris-champs-105_jpg.rf.4aba4997e5e66f5f03c31b8c491b0187
# 📂 Kaydedildi: vehicle/Paris/09_paris-champs-590_jpg.rf.9820b028017ff5ecd5529f1ed59a7f70
# 📂 Kaydedildi: vehicle/Paris/10_paris-champs-1161_jpg.rf.d749a327059811a66d062627d50fcc9e
# 🎉 Tüm görseller kaydedildi.

# %%
import os
import cv2
import torch
import numpy as np
from tqdm import tqdm
from pathlib import Path
from collections import defaultdict
import torchvision.transforms as T

# === AYARLAR ===
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
MODEL_PATH = "road-tr-od-ss-70-30-results/trained_model.pth"
DATA_DIR = "yolo-seg-11042025/road-tr-od-ss/test"
OUTPUT_DIR = Path("deeplab-best-10-segmented")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# === SINIFLAR ===
CLASS_IDS = {
    'road': 1,
    'pedestrian': 2,
    'vehicle': 3
}
CLASS_COLORS = {
    1: (255, 0, 255),     # road - magenta
    2: (0, 255, 255),     # pedestrian - yellow
    3: (0, 0, 255)        # vehicle - red
}

city_keywords = {
    'istanbul': ['libadiye', 'levent', 'taksim', 'ciragan', 'barbaros', 'dolmabahce', 'bagdat', 'muallim', 'katar'],
    'paris': ['paris-champs'],
    'munih': ['munih'],
    'marsilya': ['marsilya']
}
city_translation = {
    'istanbul': 'Istanbul',
    'paris': 'Paris',
    'munih': 'Munich',
    'marsilya': 'Marseille',
    'unknown': 'Unknown'
}

def get_city(filename):
    for city, keywords in city_keywords.items():
        if any(k in filename for k in keywords):
            return city
    return 'unknown'

def overlay_mask(image, mask, cls_id, color, alpha=0.5):
    overlay = image.copy()
    region = (mask == cls_id)
    color_layer = np.zeros_like(image, dtype=np.uint8)
    color_layer[region] = color
    return cv2.addWeighted(color_layer, alpha, overlay, 1 - alpha, 0)

# === MODEL YÜKLE ===
import torchvision.models.segmentation as models
model = models.deeplabv3_mobilenet_v3_large(weights=None, num_classes=4)
model.load_state_dict(torch.load(MODEL_PATH, map_location=DEVICE))
model.eval().to(DEVICE)

# === VERİ SETİ ===
image_files = sorted([f for f in os.listdir(DATA_DIR) if f.endswith(".jpg")])
transform = T.Compose([
    T.ToTensor(),
    T.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))
])

results_per_class = {k: defaultdict(list) for k in CLASS_IDS}

# === INFERENCING ===
print("🔍 İnferencing başlıyor...")
for fname in tqdm(image_files):
    name = os.path.splitext(fname)[0]
    img_path = os.path.join(DATA_DIR, fname)
    mask_path = os.path.join(DATA_DIR, name + "_mask.png")

    image = cv2.imread(img_path)
    if image is None:
        continue
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
    if mask is None or image.shape[:2] != mask.shape:
        continue

    input_tensor = transform(image).unsqueeze(0).to(DEVICE)
    with torch.no_grad():
        pred = model(input_tensor)['out'].squeeze().argmax(0).cpu().numpy()

    # === METRİK HESAPLAMA ===
    for label, cls_id in CLASS_IDS.items():
        pred_mask = (pred == cls_id).astype(np.uint8)
        gt_mask = (mask == cls_id).astype(np.uint8)

        inter = np.logical_and(pred_mask, gt_mask).sum()
        union = np.logical_or(pred_mask, gt_mask).sum()
        iou = inter / (union + 1e-6)

        if inter > 0:
            city = get_city(name)
            results_per_class[label][city].append({
                "iou": iou,
                "image": image.copy(),
                "gt": mask.copy(),
                "pred": pred.copy(),
                "name": name
            })

print("✅ İnferencing tamamlandı.")

# === EN İYİ 10 KAYDET ===
for label, cls_id in CLASS_IDS.items():
    for city, records in results_per_class[label].items():
        top10 = sorted(records, key=lambda x: -x['iou'])[:10]
        city_name = city_translation.get(city, city)
        save_dir = OUTPUT_DIR / label / city_name
        save_dir.mkdir(parents=True, exist_ok=True)

        for i, r in enumerate(top10, 1):
            name = f"{i:02d}_{r['name']}"
            dst = save_dir / name
            dst.mkdir(parents=True, exist_ok=True)

            # Maskeleri renkle kapla
            img = r['image']
            gt_masked = overlay_mask(img, r['gt'], cls_id, CLASS_COLORS[cls_id])
            pred_masked = overlay_mask(img, r['pred'], cls_id, CLASS_COLORS[cls_id])

            cv2.imwrite(str(dst / "original.jpg"), img)
            cv2.imwrite(str(dst / "mask.jpg"), gt_masked)
            cv2.imwrite(str(dst / "prediction.jpg"), pred_masked)

            print(f"📂 Kaydedildi: {label}/{city_name}/{name}")

print("🎉 Tüm görseller kaydedildi.")
# Out:
# 🔍 İnferencing başlıyor...
# 100%|██████████| 1316/1316 [02:38<00:00,  8.29it/s]
# ✅ İnferencing tamamlandı.
# 📂 Kaydedildi: road/Istanbul/01_muallimnaci-286_jpg.rf.0fdc57447155fcb982daae2e0539cd26
# 📂 Kaydedildi: road/Istanbul/02_bagdat-1-24_jpg.rf.72676e72054cf6522faf8369ba6bbced
# 📂 Kaydedildi: road/Istanbul/03_bagdat-1-342_jpg.rf.e377aa9fe6192b90ded430a02ee67c64
# 📂 Kaydedildi: road/Istanbul/04_bagdat-1-124_jpg.rf.96ffc5454f54898428232bfb72c8bdb4
# 📂 Kaydedildi: road/Istanbul/05_libadiye-318_jpg.rf.4a3330313065e0bced7acc55c066ec79
# 📂 Kaydedildi: road/Istanbul/06_bagdat-1-387_jpg.rf.e56c8ae432e48c6ad3ab1c8ec4879c61
# 📂 Kaydedildi: road/Istanbul/07_taksim-100_jpg.rf.be60ff28fe4d26482a6e2faebc740bfb
# 📂 Kaydedildi: road/Paris/04_paris-champs-265_jpg.rf.77f7e4b5cb3f1e2a5f6da6d51f3fd5b1
# 📂 Kaydedildi: road/Paris/05_paris-champs-90_jpg.rf.a1daf507640b1fe30d5a9eec028a453f
# 📂 Kaydedildi: road/Paris/06_paris-champs-346_jpg.rf.2328ce637fe594b226e69d34b8d61f61
# 📂 Kaydedildi: road/Paris/07_paris-champs-1122_jpg.rf.be77ec584e97f9b8e4611883b9050e33
# 📂 Kaydedildi: road/Paris/08_paris-champs-590_jpg.rf.9820b028017ff5ecd5529f1ed59a7f70
# 📂 Kaydedildi: road/Paris/09_paris-champs-888_jpg.rf.38b4f81046b3bde3d4f7f50abdf3684e
# 📂 Kaydedildi: road/Paris/10_paris-champs-1025_jpg.rf.3d9ad66f47a9feee33ac937238525116
# 📂 Kaydedildi: pedestrian/Unknown/01_Street-View-360_jpg.rf.ea9f21dce83c6f513dd582d9341a1f01
# 📂 Kaydedildi: pedestrian/Istanbul/01_taksim-59_jpg.rf.68ecf21d82130c13afd481794e3ba40c
# 📂 Kaydedildi: pedestrian/Istanbul/02_taksim-66_jpg.rf.8e901867d42dfce8c95b15531a716b28
# 📂 Kaydedildi: pedestrian/Istanbul/03_taksim-62_jpg.rf.03a654e5384eab5f0c7935ba82953237
# 📂 Kaydedildi: pedestrian/Istanbul/04_ciragan-87_jpg.rf.e7a2df028b6a33c06d19744d355fcfbb
# 📂 Kaydedildi: pedestrian/Istanbul/05_ciragan-93_jpg.rf.6fa41a82f441277ac8c714d0c0832d99
# 📂 Kaydedildi: pedestrian/Istanbul/06_bagdat-1-209_jpg.rf.dfca72f24d1ebfd2be685ae87a0d600b
# 📂 Kaydedildi: pedestrian/Istanbul/07_taksim-76_jpg.rf.0b5a41fd1148d754a6986450a046aac4
# 📂 Kaydedildi: pedestrian/Istanbul/08_katar-119_jpg.rf.1f2e399f83717dd4e715f6ff3d9e88de
# 📂 Kaydedildi: pedestrian/Istanbul/09_taksim-100_jpg.rf.be60ff28fe4d26482a6e2faebc740bfb
# 📂 Kaydedildi: pedestrian/Istanbul/10_katar-33_jpg.rf.ed72f66a004131ae53329e5298c4874e
# 📂 Kaydedildi: pedestrian/Marseille/01_marsilya-1374_jpg.rf.da46308adf734e1a5a110347e4593c69
# 📂 Kaydedildi: pedestrian/Marseille/02_marsilya-1481_jpg.rf.8de74387e0b55d966641f070fb07d3c2
# 📂 Kaydedildi: pedestrian/Marseille/03_marsilya-1329_jpg.rf.6d2f128997c58bd39147374b97c654ac
# 📂 Kaydedildi: pedestrian/Marseille/04_marsilya-1197_jpg.rf.dab0c290cb41524a48925464580fc101
# 📂 Kaydedildi: pedestrian/Marseille/05_marsilya-1838_jpg.rf.a44423486375bcabe92b850e21152b16
# 📂 Kaydedildi: pedestrian/Marseille/06_marsilya-719_jpg.rf.4a8a64c0fa5b24eed5cb0671709df9f1
# 📂 Kaydedildi: vehicle/Munich/05_munih-isar-192_jpg.rf.40f4f4fce3c71d27a5e095be8619be6c
# 📂 Kaydedildi: vehicle/Munich/06_munih-einstein-481_jpg.rf.1fd68f8cf291e7130b6fcf9b325cc107
# 📂 Kaydedildi: vehicle/Munich/07_munih-leopold-403_jpg.rf.ae3eeaa06b674ecad4bdcd0bda98ea12
# 📂 Kaydedildi: vehicle/Munich/08_munih-einstein-904_jpg.rf.fbefc129e2e23abc50212215372c5213
# 📂 Kaydedildi: vehicle/Munich/09_munih-leopold-384_jpg.rf.b6c96abe9316ee2e65d6749f48202493
# 📂 Kaydedildi: vehicle/Munich/10_munih-einstein-1460_jpg.rf.1dbf16d184b05ab3a00b5155548770d2
# 📂 Kaydedildi: vehicle/Paris/01_paris-champs-313_jpg.rf.9252bacd58f48e8bd00973ca7c5ea672
# 📂 Kaydedildi: vehicle/Paris/02_paris-champs-511_jpg.rf.7e5f52c73813906258ec9bfea0b86e50
# 📂 Kaydedildi: vehicle/Paris/03_paris-champs-53_jpg.rf.d5ef5c580a5039dcc5514d6afbd2c2bc
# 📂 Kaydedildi: vehicle/Paris/04_paris-champs-812_jpg.rf.d944b8fa029d7afbf5ceea6c32e3709c
# 📂 Kaydedildi: vehicle/Paris/05_paris-champs-500_jpg.rf.73174bc41fb463fb25e57776ad7d7d8f
# 📂 Kaydedildi: vehicle/Paris/06_paris-champs-1061_jpg.rf.05388c8f75a41e294add30756f298597
# 📂 Kaydedildi: vehicle/Paris/07_paris-champs-1118_jpg.rf.434048b6d6b7f4b4e5aabf9fa8a032fe
# 📂 Kaydedildi: vehicle/Paris/08_paris-champs-105_jpg.rf.4aba4997e5e66f5f03c31b8c491b0187
# 📂 Kaydedildi: vehicle/Paris/09_paris-champs-590_jpg.rf.9820b028017ff5ecd5529f1ed59a7f70
# 📂 Kaydedildi: vehicle/Paris/10_paris-champs-1161_jpg.rf.d749a327059811a66d062627d50fcc9e
# 🎉 Tüm görseller kaydedildi.

# %%
import os
import cv2
import torch
import numpy as np
from tqdm import tqdm
from pathlib import Path
from collections import defaultdict
import torchvision.transforms as T
from PIL import Image  # 👈 300 DPI için eklendi

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
MODEL_PATH = "road-tr-od-ss-70-30-results/trained_model.pth"
DATA_DIR = "yolo-seg-11042025/road-tr-od-ss/test"
OUTPUT_DIR = Path("deeplab-best-10-segmented-300dpi")  # 👈 GÜNCELLENDİ
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# Class IDs (model output indices)
CLASS_IDS = {
    'road': 1,
    'pedestrian': 2,
    'vehicle': 3
}

CLASS_COLORS = {
    1: (255, 0, 255),     # road - magenta
    2: (0, 255, 255),     # pedestrian - yellow
    3: (0, 0, 255)        # vehicle - red
}

MASK_COLOR = (0, 255, 0)  # green – GT maskeleri için

city_keywords = {
    'istanbul': ['libadiye', 'levent', 'taksim', 'ciragan', 'barbaros', 'dolmabahce', 'bagdat', 'muallim', 'katar'],
    'paris': ['paris-champs'],
    'munih': ['munih'],
    'marsilya': ['marsilya']
}
city_translation = {
    'istanbul': 'Istanbul',
    'paris': 'Paris',
    'munih': 'Munich',
    'marsilya': 'Marseille',
    'unknown': 'Unknown'
}

def get_city(filename):
    for city, keywords in city_keywords.items():
        if any(k in filename for k in keywords):
            return city
    return 'unknown'

def overlay_mask(image, mask, cls_id, color, alpha=0.5):
    overlay = image.copy()
    region = (mask == cls_id)
    color_layer = np.zeros_like(image, dtype=np.uint8)
    color_layer[region] = color
    return cv2.addWeighted(color_layer, alpha, overlay, 1 - alpha, 0)

def save_with_dpi(img_array, path, dpi=(300, 300)):
    img_rgb = cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB)
    img_pil = Image.fromarray(img_rgb)
    img_pil.save(path, dpi=dpi, quality=95)

# === MODEL YÜKLE ===
import torchvision.models.segmentation as models
model = models.deeplabv3_mobilenet_v3_large(weights=None, num_classes=4)
model.load_state_dict(torch.load(MODEL_PATH, map_location=DEVICE))
model.eval().to(DEVICE)

# === VERİ SETİ ===
image_files = sorted([f for f in os.listdir(DATA_DIR) if f.endswith(".jpg")])
transform = T.Compose([
    T.ToTensor(),
    T.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))
])

results_per_class = {k: defaultdict(list) for k in CLASS_IDS}

# === INFERENCING ===
print("🔍 İnferencing başlıyor...")
for fname in tqdm(image_files):
    name = os.path.splitext(fname)[0]
    img_path = os.path.join(DATA_DIR, fname)
    mask_path = os.path.join(DATA_DIR, name + "_mask.png")

    image = cv2.imread(img_path)
    if image is None:
        continue
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
    if mask is None or image.shape[:2] != mask.shape:
        continue

    input_tensor = transform(image).unsqueeze(0).to(DEVICE)
    with torch.no_grad():
        pred = model(input_tensor)['out'].squeeze().argmax(0).cpu().numpy()

    for label, cls_id in CLASS_IDS.items():
        pred_mask = (pred == cls_id).astype(np.uint8)
        gt_mask = (mask == cls_id).astype(np.uint8)

        inter = np.logical_and(pred_mask, gt_mask).sum()
        union = np.logical_or(pred_mask, gt_mask).sum()
        iou = inter / (union + 1e-6)

        if inter > 0:
            city = get_city(name)
            results_per_class[label][city].append({
                "iou": iou,
                "image": image.copy(),
                "gt": mask.copy(),
                "pred": pred.copy(),
                "name": name
            })

print("✅ İnferencing tamamlandı.")

# === EN İYİ 10 KAYDET ===
for label, cls_id in CLASS_IDS.items():
    for city, records in results_per_class[label].items():
        top10 = sorted(records, key=lambda x: -x['iou'])[:10]
        city_name = city_translation.get(city, city)
        save_dir = OUTPUT_DIR / label / city_name
        save_dir.mkdir(parents=True, exist_ok=True)

        for i, r in enumerate(top10, 1):
            name = f"{i:02d}_{r['name']}"
            dst = save_dir / name
            dst.mkdir(parents=True, exist_ok=True)

            img = r['image']
            gt_masked = overlay_mask(img, r['gt'], cls_id, MASK_COLOR)
            pred_masked = overlay_mask(img, r['pred'], cls_id, CLASS_COLORS[cls_id])

            save_with_dpi(img, dst / "original.jpg")
            save_with_dpi(gt_masked, dst / "mask.jpg")
            save_with_dpi(pred_masked, dst / "prediction.jpg")

            print(f"📂 Kaydedildi: {label}/{city_name}/{name}")

print("🎉 Tüm görseller 300 DPI ile kaydedildi.")
# Out:
# 🔍 İnferencing başlıyor...
# 100%|██████████| 1316/1316 [26:56<00:00,  1.23s/it]
# ✅ İnferencing tamamlandı.
# 📂 Kaydedildi: road/Istanbul/01_muallimnaci-286_jpg.rf.0fdc57447155fcb982daae2e0539cd26
# 📂 Kaydedildi: road/Istanbul/02_bagdat-1-24_jpg.rf.72676e72054cf6522faf8369ba6bbced
# 📂 Kaydedildi: road/Istanbul/03_bagdat-1-342_jpg.rf.e377aa9fe6192b90ded430a02ee67c64
# 📂 Kaydedildi: road/Istanbul/04_bagdat-1-124_jpg.rf.96ffc5454f54898428232bfb72c8bdb4
# 📂 Kaydedildi: road/Istanbul/05_libadiye-318_jpg.rf.4a3330313065e0bced7acc55c066ec79
# 📂 Kaydedildi: road/Istanbul/06_bagdat-1-387_jpg.rf.e56c8ae432e48c6ad3ab1c8ec4879c61
# 📂 Kaydedildi: road/Istanbul/07_taksim-100_jpg.rf.be60ff28fe4d26482a6e2faebc740bfb
# 📂 Kaydedildi: road/Istanbul/08_bagdat-1-318_jpg.rf.beb44ee2457786f154172f6e2c5d0770
# 📂 Kaydedildi: road/Istanbul/09_muallimnaci-1038_jpg.rf.310083c7558ce84d0e315011a4e317b8
# 📂 Kaydedildi: road/Istanbul/10_libadiye-539_jpg.rf.72dd10809b7772d1a0a7df22e3bc90ef
# 📂 Kaydedildi: road/Marseille/01_marsilya2-564_jpg.rf.c5b3035f8b914bd589655a2ae9fdffb4
# 📂 Kaydedildi: road/Marseille/02_marsilya-1846_jpg.rf.25b5db748d153240c4f47bf857b0de03
# 📂 Kaydedildi: road/Marseille/03_marsilya2-166_jpg.rf.5212b68ae45f6fd7ec14eb68c3d1b788
# 📂 Kaydedildi: road/Marseille/04_marsilya2-201_jpg.rf.3bf0949ab14b281cb225bed6fec15671
# 📂 Kaydedildi: road/Marseille/05_marsilya2-530_jpg.rf.2f2339ee8aad0dc835d96b23b7f5da86
# 📂 Kaydedildi: road/Marseille/06_marsilya2-664_jpg.rf.02736eddd42812648b735b1920817f9e
# 📂 Kaydedildi: road/Marseille/07_marsilya-791_jpg.rf.164ef7eb4b9493529af5027eb594a023
# 📂 Kaydedildi: road/Marseille/08_marsilya-74_jpg.rf.a5dd5b6097af4e5632fd6168fb0be798
# 📂 Kaydedildi: road/Marseille/09_marsilya-304_jpg.rf.2e7ae3fadbfc2697c863ff6598e86786
# 📂 Kaydedildi: road/Marseille/10_marsilya-149_jpg.rf.2030b2bb37a2e6d26cc5961e83ecef0d
# 📂 Kaydedildi: road/Munich/01_munih-leopold-464_jpg.rf.8a2140ee12ed1acff8fdf7445911b189
# 📂 Kaydedildi: road/Munich/02_munih-leopold-401_jpg.rf.7cf584421105e5e397758447f1fa1066
# 📂 Kaydedildi: road/Munich/03_munih-leopold-227_jpg.rf.a5ba736570b3ef750ac3877f62fb37bf
# 📂 Kaydedildi: road/Munich/04_munih-einstein-301_jpg.rf.a6fdf794cb6d6238a79e8d5c29203676
# 📂 Kaydedildi: road/Munich/05_munih-einstein-575_jpg.rf.6565093ee31107990de5ee8a9f1e47c9
# 📂 Kaydedildi: road/Munich/06_munih-leopold-392_jpg.rf.6a40fca9b41da78325a934026c048f96
# 📂 Kaydedildi: road/Munich/07_munih-einstein-885_jpg.rf.ca9beecd5f7268eb09bd4bbca7976c9d
# 📂 Kaydedildi: road/Munich/08_munih-leopold-228_jpg.rf.68c7cdfbf787b974abf69fc933b6e243
# 📂 Kaydedildi: road/Munich/09_munih-leopold-286_jpg.rf.96a9c76ab65e8585362ef0f50af62428
# 📂 Kaydedildi: road/Munich/10_munih-leopold-218_jpg.rf.89f8ce789810737f5209088f44570fe3
# 📂 Kaydedildi: road/Paris/01_paris-champs-1408_jpg.rf.e5a70936305a6289a92370eb16bdd62f
# 📂 Kaydedildi: road/Paris/02_paris-champs-1048_jpg.rf.6f459c5b392a12ca3f7df80ea4ac090b
# 📂 Kaydedildi: road/Paris/03_paris-champs-1047_jpg.rf.ad7a970bd89cd4fcb39f5b791e46f788
# 📂 Kaydedildi: road/Paris/04_paris-champs-265_jpg.rf.77f7e4b5cb3f1e2a5f6da6d51f3fd5b1
# 📂 Kaydedildi: road/Paris/05_paris-champs-90_jpg.rf.a1daf507640b1fe30d5a9eec028a453f
# 📂 Kaydedildi: road/Paris/06_paris-champs-346_jpg.rf.2328ce637fe594b226e69d34b8d61f61
# 📂 Kaydedildi: road/Paris/07_paris-champs-1122_jpg.rf.be77ec584e97f9b8e4611883b9050e33
# 📂 Kaydedildi: road/Paris/08_paris-champs-590_jpg.rf.9820b028017ff5ecd5529f1ed59a7f70
# 📂 Kaydedildi: road/Paris/09_paris-champs-888_jpg.rf.38b4f81046b3bde3d4f7f50abdf3684e
# 📂 Kaydedildi: road/Paris/10_paris-champs-1025_jpg.rf.3d9ad66f47a9feee33ac937238525116
# 📂 Kaydedildi: pedestrian/Unknown/01_Street-View-360_jpg.rf.ea9f21dce83c6f513dd582d9341a1f01
# 📂 Kaydedildi: pedestrian/Istanbul/01_taksim-59_jpg.rf.68ecf21d82130c13afd481794e3ba40c
# 📂 Kaydedildi: pedestrian/Istanbul/02_taksim-66_jpg.rf.8e901867d42dfce8c95b15531a716b28
# 📂 Kaydedildi: pedestrian/Istanbul/03_taksim-62_jpg.rf.03a654e5384eab5f0c7935ba82953237
# 📂 Kaydedildi: pedestrian/Istanbul/04_ciragan-87_jpg.rf.e7a2df028b6a33c06d19744d355fcfbb
# 📂 Kaydedildi: pedestrian/Istanbul/05_ciragan-93_jpg.rf.6fa41a82f441277ac8c714d0c0832d99
# 📂 Kaydedildi: pedestrian/Istanbul/06_bagdat-1-209_jpg.rf.dfca72f24d1ebfd2be685ae87a0d600b
# 📂 Kaydedildi: pedestrian/Istanbul/07_taksim-76_jpg.rf.0b5a41fd1148d754a6986450a046aac4
# 📂 Kaydedildi: pedestrian/Istanbul/08_katar-119_jpg.rf.1f2e399f83717dd4e715f6ff3d9e88de
# 📂 Kaydedildi: pedestrian/Istanbul/09_taksim-100_jpg.rf.be60ff28fe4d26482a6e2faebc740bfb
# 📂 Kaydedildi: pedestrian/Istanbul/10_katar-33_jpg.rf.ed72f66a004131ae53329e5298c4874e
# 📂 Kaydedildi: pedestrian/Marseille/01_marsilya-1374_jpg.rf.da46308adf734e1a5a110347e4593c69
# 📂 Kaydedildi: pedestrian/Marseille/02_marsilya-1481_jpg.rf.8de74387e0b55d966641f070fb07d3c2
# 📂 Kaydedildi: pedestrian/Marseille/03_marsilya-1329_jpg.rf.6d2f128997c58bd39147374b97c654ac
# 📂 Kaydedildi: pedestrian/Marseille/04_marsilya-1197_jpg.rf.dab0c290cb41524a48925464580fc101
# 📂 Kaydedildi: pedestrian/Marseille/05_marsilya-1838_jpg.rf.a44423486375bcabe92b850e21152b16
# 📂 Kaydedildi: pedestrian/Marseille/06_marsilya-719_jpg.rf.4a8a64c0fa5b24eed5cb0671709df9f1
# 📂 Kaydedildi: pedestrian/Marseille/07_marsilya-1209_jpg.rf.f088236aee5250caf4c8d026c6393d19
# 📂 Kaydedildi: pedestrian/Marseille/08_marsilya-1419_jpg.rf.1bee920003017825e7994581d4de9c83
# 📂 Kaydedildi: pedestrian/Marseille/09_marsilya-1510_jpg.rf.64d72427f0becd9a3f4263f445f73d83
# 📂 Kaydedildi: pedestrian/Marseille/10_marsilya-978_jpg.rf.eb8819256bfc90461173da955c2221f2
# 📂 Kaydedildi: pedestrian/Munich/01_munih-einstein-1369_jpg.rf.342ed231b8cd9035efe180b4ce6da8b9
# 📂 Kaydedildi: pedestrian/Munich/02_munih-leopold-301_jpg.rf.ff557977dae3ab5adecd41559b9014a3
# 📂 Kaydedildi: pedestrian/Munich/03_munih-einstein-1100_jpg.rf.7302b597acb80b2730caf02a2f51baf7
# 📂 Kaydedildi: pedestrian/Munich/04_munih-einstein-1759_jpg.rf.60d103bc2ce4910f402fc4e64156de5a
# 📂 Kaydedildi: pedestrian/Munich/05_munih-einstein-656_jpg.rf.dd3c6ca777c6cf610e8487d25b85138a
# 📂 Kaydedildi: pedestrian/Munich/06_munih-einstein-1771_jpg.rf.8c3460f19c1a38aafca789c9821993e5
# 📂 Kaydedildi: pedestrian/Munich/07_munih-einstein-696_jpg.rf.b49b1f978180c7934c04126f4df733be
# 📂 Kaydedildi: pedestrian/Munich/08_munih-einstein-1410_jpg.rf.182217d0e247b64ea8a5a00c1acf9cff
# 📂 Kaydedildi: pedestrian/Munich/09_munih-einstein-1045_jpg.rf.3ff54dce733cac05bac04014b6db8d31
# 📂 Kaydedildi: pedestrian/Munich/10_munih-einstein-1316_jpg.rf.fe05812ba329a6238e4728b4a63b6f7c
# 📂 Kaydedildi: pedestrian/Paris/01_paris-champs-1009_jpg.rf.d590a82dd10d21e04641c1ca820eef8f
# 📂 Kaydedildi: pedestrian/Paris/02_paris-champs-1092_jpg.rf.a58dc4ae4da534f1a76cac74cffd42c2
# 📂 Kaydedildi: pedestrian/Paris/03_paris-champs-105_jpg.rf.4aba4997e5e66f5f03c31b8c491b0187
# 📂 Kaydedildi: pedestrian/Paris/04_paris-champs-996_jpg.rf.ae0d75409ed2ce1f6b1e9e229b60997d
# 📂 Kaydedildi: pedestrian/Paris/05_paris-champs-952_jpg.rf.82b715af2db90208dcdb81a84da1a5de
# 📂 Kaydedildi: pedestrian/Paris/06_paris-champs-432_jpg.rf.67acd33efe27416ade289c12a53dfc82
# 📂 Kaydedildi: pedestrian/Paris/07_paris-champs-145_jpg.rf.cdf0375bd01127bf245abb3e40396a23
# 📂 Kaydedildi: pedestrian/Paris/08_paris-champs-845_jpg.rf.1d3c740a25600ee0418d02ce743f169b
# 📂 Kaydedildi: pedestrian/Paris/09_paris-champs-107_jpg.rf.bfcb3c588e3309ba8cdc0c2c4b898ae9
# 📂 Kaydedildi: pedestrian/Paris/10_paris-champs-1161_jpg.rf.d749a327059811a66d062627d50fcc9e
# 📂 Kaydedildi: vehicle/Istanbul/01_bagdat-1-172_jpg.rf.3f24ef362b31bdf0edba79bda4c29337
# 📂 Kaydedildi: vehicle/Istanbul/02_levent-79_jpg.rf.afcc4aac2de71178d1fff38d5cd4c269
# 📂 Kaydedildi: vehicle/Istanbul/03_bagdat-1-291_jpg.rf.646887f1a384178122f402b9059fc843
# 📂 Kaydedildi: vehicle/Istanbul/04_dolmabahce-42_jpg.rf.4e77d8d74c5ec137cbe2e7a2ab5566c4
# 📂 Kaydedildi: vehicle/Istanbul/05_bagdat-1-251_jpg.rf.14f84c75b738cc27b3967a0f3d4ac78c
# 📂 Kaydedildi: vehicle/Istanbul/06_bagdat-1-92_jpg.rf.1b570ee1cd514c773ba0199d50505c7e
# 📂 Kaydedildi: vehicle/Istanbul/07_taksim-6_jpg.rf.13f49bc02450c48bb4a2998540d28bf4
# 📂 Kaydedildi: vehicle/Istanbul/08_ciragan-64_jpg.rf.3e5d3dd610fef73d4078028c8610c896
# 📂 Kaydedildi: vehicle/Istanbul/09_bagdat-1-233_jpg.rf.9b0a7ff3b5684c48f4ad7cc9265f034c
# 📂 Kaydedildi: vehicle/Istanbul/10_bagdat-1-320_jpg.rf.b6901bf71058476f8db5fea5219522cd
# 📂 Kaydedildi: vehicle/Marseille/01_marsilya2-560_jpg.rf.eb7c5ee49cab69e736e338da8875d835
# 📂 Kaydedildi: vehicle/Marseille/02_marsilya2-144_jpg.rf.afe2c082f81028d6207358d679ae83c5
# 📂 Kaydedildi: vehicle/Marseille/03_marsilya2-30_jpg.rf.022fc7b0cdfa6965aff27c6ee82a78ea
# 📂 Kaydedildi: vehicle/Marseille/04_marsilya-1_jpg.rf.316f832d4b37787f2fcb836f4afac761
# 📂 Kaydedildi: vehicle/Marseille/05_marsilya2-67_jpg.rf.df95fc7cc7fff25229625f391ae2b38b
# 📂 Kaydedildi: vehicle/Marseille/06_marsilya2-364_jpg.rf.9c8a012dd5ec3cdf2015deca5d936621
# 📂 Kaydedildi: vehicle/Marseille/07_marsilya2-409_jpg.rf.719ed5f32305da0a85cd7dbebe414ed7
# 📂 Kaydedildi: vehicle/Marseille/08_marsilya-1421_jpg.rf.cd7b024d591a8df8db30b107bef55bc2
# 📂 Kaydedildi: vehicle/Marseille/09_marsilya-1286_jpg.rf.ff3cd6d23af810a8a0a57cd8aa1cb43d
# 📂 Kaydedildi: vehicle/Marseille/10_marsilya2-355_jpg.rf.a404e31f7ab88b7ebc9ca07ad9155385
# 📂 Kaydedildi: vehicle/Munich/01_munih-isar-451_jpg.rf.5edaa0908ff254b8e0609fb9e4c10567
# 📂 Kaydedildi: vehicle/Munich/02_munih-leopold-598_jpg.rf.602f834adf3eecd2bb1deeaaabf377e9
# 📂 Kaydedildi: vehicle/Munich/03_munih-einstein-301_jpg.rf.a6fdf794cb6d6238a79e8d5c29203676
# 📂 Kaydedildi: vehicle/Munich/04_munih-einstein-176_jpg.rf.f5dab2a621381c0de11fbd736a27b93d
# 📂 Kaydedildi: vehicle/Munich/05_munih-isar-192_jpg.rf.40f4f4fce3c71d27a5e095be8619be6c
# 📂 Kaydedildi: vehicle/Munich/06_munih-einstein-481_jpg.rf.1fd68f8cf291e7130b6fcf9b325cc107
# 📂 Kaydedildi: vehicle/Munich/07_munih-leopold-403_jpg.rf.ae3eeaa06b674ecad4bdcd0bda98ea12
# 📂 Kaydedildi: vehicle/Munich/08_munih-einstein-904_jpg.rf.fbefc129e2e23abc50212215372c5213
# 📂 Kaydedildi: vehicle/Munich/09_munih-leopold-384_jpg.rf.b6c96abe9316ee2e65d6749f48202493
# 📂 Kaydedildi: vehicle/Munich/10_munih-einstein-1460_jpg.rf.1dbf16d184b05ab3a00b5155548770d2
# 📂 Kaydedildi: vehicle/Paris/01_paris-champs-313_jpg.rf.9252bacd58f48e8bd00973ca7c5ea672
# 📂 Kaydedildi: vehicle/Paris/02_paris-champs-511_jpg.rf.7e5f52c73813906258ec9bfea0b86e50
# 📂 Kaydedildi: vehicle/Paris/03_paris-champs-53_jpg.rf.d5ef5c580a5039dcc5514d6afbd2c2bc
# 📂 Kaydedildi: vehicle/Paris/04_paris-champs-812_jpg.rf.d944b8fa029d7afbf5ceea6c32e3709c
# 📂 Kaydedildi: vehicle/Paris/05_paris-champs-500_jpg.rf.73174bc41fb463fb25e57776ad7d7d8f
# 📂 Kaydedildi: vehicle/Paris/06_paris-champs-1061_jpg.rf.05388c8f75a41e294add30756f298597
# 📂 Kaydedildi: vehicle/Paris/07_paris-champs-1118_jpg.rf.434048b6d6b7f4b4e5aabf9fa8a032fe
# 📂 Kaydedildi: vehicle/Paris/08_paris-champs-105_jpg.rf.4aba4997e5e66f5f03c31b8c491b0187
# 📂 Kaydedildi: vehicle/Paris/09_paris-champs-590_jpg.rf.9820b028017ff5ecd5529f1ed59a7f70
# 📂 Kaydedildi: vehicle/Paris/10_paris-champs-1161_jpg.rf.d749a327059811a66d062627d50fcc9e
# 🎉 Tüm görseller 300 DPI ile kaydedildi.
