# %%
"""
README: YOLO Detection vs. Ground Truth Per-Class, Per-City Visualizer

This script compares YOLO detection results to ground-truth labels, per class and per city,
filters the top-10 best-matching images (by IoU threshold) for each class/city combination,
and saves separate image folders for side-by-side visual inspection.
- Also supports visual zoom-ins for small objects.
- Produces 'original.jpg', 'labels.jpg', and 'detections.jpg' for each best match.
- Parallel processing is used for efficiency.

How to use:
- Update the directory paths below for your detection labels, ground truth labels, and images.
- The script will output a folder structure organized by class and city.
- Zoomed crops for small objects are included for easier visual analysis.

Requirements:
- Python 3.7+
- opencv-python
- pathlib (standard)
- numpy
- concurrent.futures (standard)
- datetime (standard)
- time (standard)

Author: Bahadir Akin Akgul
Date: 13.07.2025
"""

import cv2
import time
from pathlib import Path
from datetime import datetime
from concurrent.futures import ThreadPoolExecutor

# === SETTINGS ===
labels_dir = Path('PATH_TO_YOLO_DETECTION_LABELS')
gt_dir = Path('PATH_TO_GROUND_TRUTH_LABELS')
images_dir = Path('PATH_TO_IMAGES')
output_dir = Path('yolo-best10-perclass-city-visuals')
output_dir.mkdir(parents=True, exist_ok=True)

iou_threshold = 0.5
class_names = ['pedestrian', 'road', 'vehicle']
class_ids = {'pedestrian': 0, 'road': 1, 'vehicle': 2}
colors = {
    'gt': (0, 255, 0),       # green for ground truth
    0: (0, 255, 255),        # yellow for pedestrian
    1: (0, 0, 0),            # black for road
    2: (0, 0, 255)           # red for vehicle
}

city_keywords = {
    'istanbul': ['libadiye', 'levent', 'taksim', 'ciragan', 'barbaros', 'dolmabahce', 'bagdat', 'muallim', 'katar'],
    'paris': ['paris-champs'],
    'munich': ['munih'],
    'marseille': ['marsilya']
}

city_translation = {
    'istanbul': 'Istanbul',
    'paris': 'Paris',
    'munich': 'Munich',
    'marseille': 'Marseille',
    'unknown': 'Unknown'
}

def now():
    return datetime.now().strftime('%H:%M:%S')

def calculate_iou(boxA, boxB):
    xA, yA, wA, hA = boxA
    xa1, ya1, xa2, ya2 = xA - wA / 2, yA - hA / 2, xA + wA / 2, yA + hA / 2
    xB, yB, wB, hB = boxB
    xb1, yb1, xb2, yb2 = xB - wB / 2, yB - hB / 2, xB + wB / 2, yB + hB / 2

    inter_x1 = max(xa1, xb1)
    inter_y1 = max(ya1, yb1)
    inter_x2 = min(xa2, xb2)
    inter_y2 = min(ya2, yb2)
    inter_area = max(0, inter_x2 - inter_x1) * max(0, inter_y2 - inter_y1)
    area_a = (xa2 - xa1) * (ya2 - ya1)
    area_b = (xb2 - xb1) * (yb2 - yb1)
    return inter_area / (area_a + area_b - inter_area + 1e-6)

def draw_single_class_boxes(image, boxes, classes, cls_id, color_override=None, is_gt=False):
    h, w = image.shape[:2]
    for cls, box in zip(classes, boxes):
        if cls != cls_id:
            continue
        x_c, y_c, bw, bh = box
        x1 = int((x_c - bw / 2) * w)
        y1 = int((y_c - bh / 2) * h)
        x2 = int((x_c + bw / 2) * w)
        y2 = int((y_c + bh / 2) * h)

        color = color_override if color_override else colors[cls]
        thickness = 1
        if cls_id == 1:  # road
            thickness = 2
        cv2.rectangle(image, (x1, y1), (x2, y2), color, thickness)
    return image

def check_overlap(new_box, existing_boxes):
    x1, y1, x2, y2 = new_box
    for ex in existing_boxes:
        ex1, ey1, ex2, ey2 = ex
        if not (x2 < ex1 or x1 > ex2 or y2 < ey1 or y1 > ey2):
            return True
    return False

def get_city_from_name(name):
    for city, keywords in city_keywords.items():
        if any(keyword in name for keyword in keywords):
            return city
    return 'unknown'

def process_file_for_class(cls_name):
    start = time.time()
    cls_id = class_ids[cls_name]
    results_by_city = {city: [] for city in city_keywords}
    results_by_city['unknown'] = []
    txt_files = list(labels_dir.glob("*.txt"))

    print(f"[{now()}] 🚀 Starting: {cls_name.upper()}")

    for txt_file in txt_files:
        image_stem = txt_file.stem
        image_file = images_dir / f"{image_stem}.jpg"
        if not image_file.exists():
            continue

        img = cv2.imread(str(image_file))
        if img is None:
            continue

        gt_path = gt_dir / txt_file.name
        if not gt_path.exists():
            continue

        with open(gt_path) as f:
            gt_lines = [line.strip().split() for line in f if line.strip()]
        gt_classes = [int(l[0]) for l in gt_lines]
        gt_boxes = [list(map(float, l[1:5])) for l in gt_lines]

        with open(txt_file) as f:
            det_lines = [line.strip().split() for line in f if line.strip()]
        det_classes = [int(l[0]) for l in det_lines]
        det_boxes = [list(map(float, l[1:5])) for l in det_lines]

        filtered_det_boxes = []
        filtered_det_classes = []
        matched_gt = set()

        for i, gt_box in enumerate(gt_boxes):
            if gt_classes[i] != cls_id:
                continue
            for j, det_box in enumerate(det_boxes):
                if det_classes[j] != cls_id:
                    continue
                if calculate_iou(gt_box, det_box) >= iou_threshold:
                    filtered_det_boxes.append(det_box)
                    filtered_det_classes.append(cls_id)
                    matched_gt.add(i)
                    break

        match_count = len(matched_gt)
        if match_count > 0:
            city = get_city_from_name(image_stem)
            results_by_city[city].append({
                "match": match_count,
                "image": img,
                "gt_boxes": gt_boxes,
                "gt_classes": gt_classes,
                "det_boxes": filtered_det_boxes,
                "det_classes": filtered_det_classes,
                "name": txt_file.stem
            })

    for city, results in results_by_city.items():
        city_label = city_translation.get(city, city.capitalize())
        city_output = output_dir / cls_name / city_label
        city_output.mkdir(parents=True, exist_ok=True)

        top10 = sorted(results, key=lambda x: x["match"], reverse=True)[:10]

        for i, result in enumerate(top10, 1):
            base_name = f"{i:02d}_{result['name']}"
            single_output = city_output / base_name
            single_output.mkdir(parents=True, exist_ok=True)

            ori_img = result["image"]
            gt_img = draw_single_class_boxes(
                ori_img.copy(), result["gt_boxes"], result["gt_classes"],
                cls_id, color_override=colors['gt'], is_gt=True)

            det_img = draw_single_class_boxes(
                ori_img.copy(), result["det_boxes"], result["det_classes"],
                cls_id, color_override=colors[cls_id], is_gt=False)

            h, w = ori_img.shape[:2]
            zoom_overlay = det_img.copy()
            max_zoom_size = 96
            zoom_positions = []

            for k, box in enumerate(result["det_boxes"]):
                x_c, y_c, bw, bh = box
                box_w = int(bw * w)
                box_h = int(bh * h)
                if box_w >= 32 or box_h >= 32:
                    continue

                x1 = max(0, int((x_c - bw / 2) * w))
                y1 = max(0, int((y_c - bh / 2) * h))
                x2 = min(w, int((x_c + bw / 2) * w))
                y2 = min(h, int((y_c + bh / 2) * h))
                crop = ori_img[y1:y2, x1:x2]
                if crop.size <= 0:
                    continue

                zoom_factor = min(max_zoom_size // max(box_w, box_h), 4)
                zoom_w, zoom_h = box_w * zoom_factor, box_h * zoom_factor
                resized = cv2.resize(crop, (zoom_w, zoom_h), interpolation=cv2.INTER_LINEAR)
                cv2.rectangle(resized, (0, 0), (zoom_w - 1, zoom_h - 1), colors[cls_id], 2)

                paste_x, paste_y = x1, y1 - zoom_h - 10
                shift = 5
                while check_overlap((paste_x, paste_y, paste_x + zoom_w, paste_y + zoom_h), zoom_positions):
                    paste_y -= shift
                    if paste_y < 0:
                        paste_y = y2 + 10
                    if paste_y + zoom_h > h:
                        break

                if paste_y + zoom_h > h or paste_x + zoom_w > w:
                    continue

                zoom_positions.append((paste_x, paste_y, paste_x + zoom_w, paste_y + zoom_h))
                zoom_overlay[paste_y:paste_y+zoom_h, paste_x:paste_x+zoom_w] = resized

                arrow_start = (x1 + box_w // 2, y1)
                arrow_end = (paste_x + zoom_w // 2, paste_y + zoom_h - 1)
                cv2.arrowedLine(zoom_overlay, arrow_start, arrow_end, (255, 0, 255), 1, tipLength=0.2)

            cv2.imwrite(str(single_output / "original.jpg"), ori_img)
            cv2.imwrite(str(single_output / "labels.jpg"), gt_img)
            cv2.imwrite(str(single_output / "detections.jpg"), zoom_overlay)

            print(f"[{now()}] 📂 {cls_name.upper()} - {city_label} - Saved: {base_name}")

    print(f"[{now()}] ✅ {cls_name.upper()} finished ({time.time()-start:.1f} sec)")

# Parallel processing per class
with ThreadPoolExecutor(max_workers=3) as executor:
    executor.map(process_file_for_class, class_names)
# Out:
# [20:32:07] 🚀 Başlıyor: PEDESTRIAN
# [20:32:07] 🚀 Başlıyor: ROAD
# [20:32:07] 🚀 Başlıyor: VEHICLE
# [20:32:24] 📂 ROAD - Istanbul - Kaydedildi: 01_katar-482_jpg.rf.a2522fa55e30b6b22de87cdd7b30df63
# [20:32:24] 📂 PEDESTRIAN - Istanbul - Kaydedildi: 01_bagdat-1-382_jpg.rf.4ae73d9941bdea605dc2dbd0280ed888
# [20:32:24] 📂 ROAD - Istanbul - Kaydedildi: 02_bagdat-1-293_jpg.rf.74450bad7504458a2a6298c5ec855fd1
# [20:32:24] 📂 PEDESTRIAN - Istanbul - Kaydedildi: 02_bagdat-1-422_jpg.rf.7e3ee5b10b2373426f0701098ce3a18e
# [20:32:24] 📂 ROAD - Istanbul - Kaydedildi: 03_bagdat-1-4_jpg.rf.665736ea603fff5ddba9e99f9fb4ecf7
# [20:32:24] 📂 PEDESTRIAN - Istanbul - Kaydedildi: 03_bagdat-1-381_jpg.rf.4ff3273da5bf43f5739f9de23572004d
# [20:32:24] 📂 ROAD - Istanbul - Kaydedildi: 04_muallimnaci-284_jpg.rf.dd3b9eca3aaf5054e147bd82721f6121
# [20:32:24] 📂 PEDESTRIAN - Istanbul - Kaydedildi: 04_bagdat-1-257_jpg.rf.74ab909f0e2a8232f83b52696f2a6bd3
# [20:32:24] 📂 ROAD - Istanbul - Kaydedildi: 05_ciragan-108_jpg.rf.2e2117ac297317c91a05682123abc5a0
# [20:32:24] 📂 PEDESTRIAN - Istanbul - Kaydedildi: 05_bagdat-1-69_jpg.rf.91b5407f9882d6c58729555b404d8612
# [20:32:24] 📂 ROAD - Istanbul - Kaydedildi: 06_katar-1104_jpg.rf.35de596930f413624c5a3d3038216dfb
# [20:32:24] 📂 PEDESTRIAN - Istanbul - Kaydedildi: 06_bagdat-1-358_jpg.rf.e2d263ed5a9d12d667d2329a3bc2a3bf
# [20:32:24] 📂 ROAD - Istanbul - Kaydedildi: 07_bagdat-1-440_jpg.rf.516a2201d690aecaf570b43655d14236
# [20:32:24] 📂 PEDESTRIAN - Istanbul - Kaydedildi: 07_bagdat-1-286_jpg.rf.cf6c6ea0eee710e5596cc8fc6dce2010
# [20:32:24] 📂 ROAD - Istanbul - Kaydedildi: 08_katar-687_jpg.rf.8f48c9a40d7c10a6a4a9df01fceef9f1
# [20:32:24] 📂 PEDESTRIAN - Istanbul - Kaydedildi: 08_bagdat-1-417_jpg.rf.5a5bdd5ae05d22998aa484017a56998b
# [20:32:24] 📂 ROAD - Istanbul - Kaydedildi: 09_bagdat-1-33_jpg.rf.f392b45498cb8d4e7029ff5a369bc88e
# [20:32:24] 📂 PEDESTRIAN - Istanbul - Kaydedildi: 09_bagdat-1-428_jpg.rf.8864fccf3ace5331fac031240ebd05a4
# [20:32:24] 📂 ROAD - Istanbul - Kaydedildi: 10_bagdat-1-339_jpg.rf.edbfbc08b14a9da7a051755d07f10040
# [20:32:24] 📂 PEDESTRIAN - Istanbul - Kaydedildi: 10_bagdat-1-284_jpg.rf.d7eb1e1c7bcb4d7df567451003c12e5f
# [20:32:24] 📂 ROAD - Paris - Kaydedildi: 01_paris-champs-426_jpg.rf.c33211b6cd4bf7dd6e8ba9a0d705b948
# [20:32:24] 📂 PEDESTRIAN - Paris - Kaydedildi: 01_paris-champs-500_jpg.rf.b12f50457c414318a6d187fddc01838e
# [20:32:24] 📂 ROAD - Paris - Kaydedildi: 02_paris-champs-1122_jpg.rf.3e360dd045d304f26e4d18aa7f07ae75
# [20:32:24] 📂 PEDESTRIAN - Paris - Kaydedildi: 02_paris-champs-381_jpg.rf.69281cab69342252b0646b60c7d78e68
# [20:32:24] 📂 ROAD - Paris - Kaydedildi: 03_paris-champs-1299_jpg.rf.ced4137cfa0ecdb8e74d80a9ee3511da
# [20:32:24] 📂 VEHICLE - Istanbul - Kaydedildi: 01_bagdat-1-443_jpg.rf.a32fec5e0045057885589929a50dbba6
# [20:32:24] 📂 PEDESTRIAN - Paris - Kaydedildi: 03_paris-champs-426_jpg.rf.c33211b6cd4bf7dd6e8ba9a0d705b948
# [20:32:24] 📂 ROAD - Paris - Kaydedildi: 04_paris-champs-888_jpg.rf.bfc4b6d2585392c1984cbfa1be86d322
# [20:32:25] 📂 VEHICLE - Istanbul - Kaydedildi: 02_levent-52_jpg.rf.74be640901ea9600c80d30451de87d3e
# [20:32:25] 📂 PEDESTRIAN - Paris - Kaydedildi: 04_paris-champs-888_jpg.rf.bfc4b6d2585392c1984cbfa1be86d322
# [20:32:25] 📂 ROAD - Paris - Kaydedildi: 05_paris-champs-1408_jpg.rf.88db03540d3eadd8b02480ed39b81998
# [20:32:25] 📂 VEHICLE - Istanbul - Kaydedildi: 03_bagdat-1-400_jpg.rf.6bfb079a34865f249ab51400f5aa068b
# [20:32:25] 📂 PEDESTRIAN - Paris - Kaydedildi: 05_paris-champs-1408_jpg.rf.88db03540d3eadd8b02480ed39b81998
# [20:32:25] 📂 ROAD - Paris - Kaydedildi: 06_paris-champs-1118_jpg.rf.ff324160d1eb8b8ab396ed7a1f62a4d4
# [20:32:25] 📂 VEHICLE - Istanbul - Kaydedildi: 04_bagdat-1-365_jpg.rf.96d2bb464a27dae6bd1d0b2a27efe6db
# [20:32:25] 📂 PEDESTRIAN - Paris - Kaydedildi: 06_paris-champs-107_jpg.rf.a8bb897342650dc4f8f6b4af342c393d
# [20:32:25] 📂 ROAD - Paris - Kaydedildi: 07_paris-champs-313_jpg.rf.83d503408cba968433dc2e62dbd0512b
# [20:32:25] 📂 VEHICLE - Istanbul - Kaydedildi: 05_bagdat-1-417_jpg.rf.5a5bdd5ae05d22998aa484017a56998b
# [20:32:25] 📂 PEDESTRIAN - Paris - Kaydedildi: 07_paris-champs-557_jpg.rf.9dce136a6c1983c905989ba78dcfeb11
# [20:32:25] 📂 ROAD - Paris - Kaydedildi: 08_paris-champs-1092_jpg.rf.b1787da04ff9cf962ce14519227e7c28
# [20:32:25] 📂 VEHICLE - Istanbul - Kaydedildi: 06_bagdat-1-416_jpg.rf.953f32e3c9e9dad6e0156a4902041d91
# [20:32:25] 📂 PEDESTRIAN - Paris - Kaydedildi: 08_paris-champs-511_jpg.rf.0f0aa065787a5a088c32c7a309706561
# [20:32:25] 📂 ROAD - Paris - Kaydedildi: 09_paris-champs-557_jpg.rf.9dce136a6c1983c905989ba78dcfeb11
# [20:32:25] 📂 VEHICLE - Istanbul - Kaydedildi: 07_bagdat-1-58_jpg.rf.91d6fc1b615eaffe9ff69cfa6b390301
# [20:32:25] 📂 PEDESTRIAN - Paris - Kaydedildi: 09_paris-champs-265_jpg.rf.640ac4c9e4df43c9a3cc168528696ba6
# [20:32:25] 📂 ROAD - Paris - Kaydedildi: 10_paris-champs-1268_jpg.rf.92ec4154015834e57f1a3df997ac6583
# [20:32:25] 📂 VEHICLE - Istanbul - Kaydedildi: 08_libadiye-185_jpg.rf.ea0ccbeb7d763558be43ba4004bc15bb
# [20:32:25] 📂 PEDESTRIAN - Paris - Kaydedildi: 10_paris-champs-641_jpg.rf.780f6398d783ea2f1f70fff804575816
# [20:32:25] 📂 ROAD - Munich - Kaydedildi: 01_munih-einstein-1316_jpg.rf.115a01d93019556e39ce341f7ae68242
# [20:32:25] 📂 VEHICLE - Istanbul - Kaydedildi: 09_bagdat-1-397_jpg.rf.20ba061b839462b53b21b971f74c8bb6
# [20:32:25] 📂 PEDESTRIAN - Munich - Kaydedildi: 01_munih-leopold-197_jpg.rf.bc55c495695b610fde9f395d54851fe0
# [20:32:25] 📂 ROAD - Munich - Kaydedildi: 02_munih-einstein-1781_jpg.rf.28e8c02be93319a73a39880218936cc9
# [20:32:25] 📂 VEHICLE - Istanbul - Kaydedildi: 10_bagdat-1-445_jpg.rf.1aefef7d483b648ded0f2b9881d58d5b
# [20:32:25] 📂 PEDESTRIAN - Munich - Kaydedildi: 02_munih-leopold-55_jpg.rf.1a8e3d85011c92265890bde0b67b4c59
# [20:32:25] 📂 ROAD - Munich - Kaydedildi: 03_munih-einstein-1460_jpg.rf.c88adc5c3b9417d71615b00e8c2d3f78
# [20:32:25] 📂 VEHICLE - Paris - Kaydedildi: 01_paris-champs-1009_jpg.rf.87b9a7ce2dd31bbde28d2be7ccb0b8fc
# [20:32:25] 📂 PEDESTRIAN - Munich - Kaydedildi: 03_munih-leopold-198_jpg.rf.1bf5a494da6ceaab68d5d83b8453afcb
# [20:32:25] 📂 ROAD - Munich - Kaydedildi: 04_munih-einstein-1025_jpg.rf.1b1dd53e82b0ac3d9996e6a232eec1d5
# [20:32:25] 📂 VEHICLE - Paris - Kaydedildi: 02_paris-champs-426_jpg.rf.c33211b6cd4bf7dd6e8ba9a0d705b948
# [20:32:25] 📂 PEDESTRIAN - Munich - Kaydedildi: 04_munih-einstein-338_jpg.rf.c86d416ef5a240ec5f2dbacf1c6bd2f4
# [20:32:25] 📂 ROAD - Munich - Kaydedildi: 05_munih-einstein-1291_jpg.rf.b09dcf58e954a102f8289727e484773d
# [20:32:25] 📂 VEHICLE - Paris - Kaydedildi: 03_paris-champs-500_jpg.rf.b12f50457c414318a6d187fddc01838e
# [20:32:25] 📂 PEDESTRIAN - Munich - Kaydedildi: 05_munih-leopold-227_jpg.rf.b2144dd9f51a61be78e5db912b29c494
# [20:32:25] 📂 ROAD - Munich - Kaydedildi: 06_munih-einstein-469_jpg.rf.e1c783b52646e69130be882045d4758e
# [20:32:25] 📂 PEDESTRIAN - Munich - Kaydedildi: 06_munih-leopold-418_jpg.rf.5cd21cf73783db3a0afc857f776b5bcb
# [20:32:25] 📂 VEHICLE - Paris - Kaydedildi: 04_paris-champs-845_jpg.rf.cafa10b66cecfcd08749b0bd83d9be30
# [20:32:25] 📂 ROAD - Munich - Kaydedildi: 07_munih-einstein-1658_jpg.rf.d29b7cfbd12ac625183dda815a12dc76
# [20:32:25] 📂 PEDESTRIAN - Munich - Kaydedildi: 07_munih-leopold-236_jpg.rf.17594dc5100b3483283f98726309ba12
# [20:32:25] 📂 VEHICLE - Paris - Kaydedildi: 05_paris-champs-143_jpg.rf.4502fa52d0418c25f1f7dcd469ab6a1e
# [20:32:25] 📂 ROAD - Munich - Kaydedildi: 08_munih-einstein-802_jpg.rf.99b072a3707e24693c47cd4b9a7a477e
# [20:32:25] 📂 VEHICLE - Paris - Kaydedildi: 06_paris-champs-1122_jpg.rf.3e360dd045d304f26e4d18aa7f07ae75
# [20:32:25] 📂 PEDESTRIAN - Munich - Kaydedildi: 08_munih-einstein-332_jpg.rf.c1b2c0f7ba0dfbc8483c1a86660bee40
# [20:32:25] 📂 ROAD - Munich - Kaydedildi: 09_munih-einstein-1050_jpg.rf.984c4a2228b24c2cb0d4971033f3c0ee
# [20:32:25] 📂 PEDESTRIAN - Munich - Kaydedildi: 09_munih-leopold-133_jpg.rf.ac63b1501299c1361a7e218d6447ff12
# [20:32:25] 📂 VEHICLE - Paris - Kaydedildi: 07_paris-champs-996_jpg.rf.1494614d996dc3261dcb900d3fbeb74f
# [20:32:25] 📂 ROAD - Munich - Kaydedildi: 10_munih-einstein-54_jpg.rf.65f852b5ef66dbba79f71ffa87252763
# [20:32:25] 📂 PEDESTRIAN - Munich - Kaydedildi: 10_munih-leopold-228_jpg.rf.8f2bd0d921b59aa3081c33027946f277
# [20:32:25] 📂 VEHICLE - Paris - Kaydedildi: 08_paris-champs-762_jpg.rf.e6bd8f9466999ea4bb4ab9cbb02cba59
# [20:32:25] 📂 ROAD - Marseille - Kaydedildi: 01_marsilya2-562_jpg.rf.79e79e5f1892304717ffe9980efb0816
# [20:32:25] 📂 VEHICLE - Paris - Kaydedildi: 09_paris-champs-381_jpg.rf.69281cab69342252b0646b60c7d78e68
# [20:32:25] 📂 PEDESTRIAN - Marseille - Kaydedildi: 01_marsilya-531_jpg.rf.6086959c55d5f7cefdd5f6120aa39aee
# [20:32:25] 📂 ROAD - Marseille - Kaydedildi: 02_marsilya-541_jpg.rf.3375977da647914e40879a06e636f1d6
# [20:32:25] 📂 VEHICLE - Paris - Kaydedildi: 10_paris-champs-1003_jpg.rf.b026a31aed06c09ac0fba40847f266b0
# [20:32:25] 📂 ROAD - Marseille - Kaydedildi: 03_marsilya-717_jpg.rf.57982131ae62385a9a8b01002de767cb
# [20:32:25] 📂 PEDESTRIAN - Marseille - Kaydedildi: 02_marsilya-530_jpg.rf.62c230e571b467c84f5f4d1724ff2999
# [20:32:25] 📂 VEHICLE - Munich - Kaydedildi: 01_munih-einstein-881_jpg.rf.7bdfcfd46d38ae0286a268087c46ba1f
# [20:32:25] 📂 ROAD - Marseille - Kaydedildi: 04_marsilya-1585_jpg.rf.0169b38e08bfb773908d06c0e6a1c348
# [20:32:25] 📂 PEDESTRIAN - Marseille - Kaydedildi: 03_marsilya-470_jpg.rf.194ac3cb5e08a4aae4847fd4b86dfa15
# [20:32:25] 📂 VEHICLE - Munich - Kaydedildi: 02_munih-einstein-1199_jpg.rf.8f84f261b4b6632a1b8ff31671aa7047
# [20:32:25] 📂 ROAD - Marseille - Kaydedildi: 05_marsilya-1062_jpg.rf.4270419462d5c520c12f345645803909
# [20:32:25] 📂 PEDESTRIAN - Marseille - Kaydedildi: 04_marsilya-542_jpg.rf.97a64ca58d3441817998dfdee2694b09
# [20:32:25] 📂 VEHICLE - Munich - Kaydedildi: 03_munih-einstein-514_jpg.rf.7459b39e2dc047ee6298a3041e9f31c1
# [20:32:25] 📂 ROAD - Marseille - Kaydedildi: 06_marsilya2-561_jpg.rf.177370c6ed4092bf98ebb829610f5e34
# [20:32:25] 📂 PEDESTRIAN - Marseille - Kaydedildi: 05_marsilya-632_jpg.rf.d3d0aaf61ecb528284c37f3a521b79dd
# [20:32:25] 📂 VEHICLE - Munich - Kaydedildi: 04_munih-leopold-464_jpg.rf.7940bb961b5fecfd457ce33c9d0281d3
# [20:32:25] 📂 ROAD - Marseille - Kaydedildi: 07_marsilya-1814_jpg.rf.2157db3df9c8110a7989a914925f2a76
# [20:32:25] 📂 PEDESTRIAN - Marseille - Kaydedildi: 06_marsilya-464_jpg.rf.8c8153f120ea16f8947489a0362330a3
# [20:32:25] 📂 ROAD - Marseille - Kaydedildi: 08_marsilya-1605_jpg.rf.81f341246b611b47e777232d7616f6d0
# [20:32:25] 📂 VEHICLE - Munich - Kaydedildi: 05_munih-einstein-885_jpg.rf.dbb4a7248ce7717d803fb034ca9bc29d
# [20:32:25] 📂 PEDESTRIAN - Marseille - Kaydedildi: 07_marsilya-362_jpg.rf.03b525c04c61794a0c38df2321fa1bc5
# [20:32:25] 📂 ROAD - Marseille - Kaydedildi: 09_marsilya2-355_jpg.rf.1d09d220f8870fb1b7d9e0c93a75da4a
# [20:32:25] 📂 VEHICLE - Munich - Kaydedildi: 06_munih-leopold-520_jpg.rf.7cf633275796cd2c22f475693ee7ac9a
# [20:32:25] 📂 PEDESTRIAN - Marseille - Kaydedildi: 08_marsilya-529_jpg.rf.e3d654f4eff17abe14edefd946b9c6db
# [20:32:25] 📂 ROAD - Marseille - Kaydedildi: 10_marsilya2-693_jpg.rf.5881dcc349e13f3697797c63441523b2
# [20:32:25] 📂 VEHICLE - Munich - Kaydedildi: 07_munih-leopold-543_jpg.rf.c0c6a74a50ecf65b74007fb8886fdddb
# [20:32:25] 📂 PEDESTRIAN - Marseille - Kaydedildi: 09_marsilya-577_jpg.rf.ad9163a55eeee73b76126a3d4ccdc0cb
# [20:32:25] 📂 ROAD - Unknown - Kaydedildi: 01_Street-View-360_jpg.rf.b60e5ea133d76f00474a0da3fe9fcb9d
# [20:32:25] ✅ ROAD tamamlandı (18.1 saniye)
# [20:32:26] 📂 VEHICLE - Munich - Kaydedildi: 08_munih-leopold-494_jpg.rf.bdfa274268304e2ad5003e4f1becb910
# [20:32:26] 📂 PEDESTRIAN - Marseille - Kaydedildi: 10_marsilya-674_jpg.rf.32f5fd36c637b4fc6e5ea911a8cb78c8
# [20:32:26] 📂 VEHICLE - Munich - Kaydedildi: 09_munih-einstein-475_jpg.rf.3be591ce92ed27c0c79259595a03a2e2
# [20:32:26] 📂 PEDESTRIAN - Unknown - Kaydedildi: 01_Street-View-360_jpg.rf.b60e5ea133d76f00474a0da3fe9fcb9d
# [20:32:26] ✅ PEDESTRIAN tamamlandı (18.2 saniye)
# [20:32:26] 📂 VEHICLE - Munich - Kaydedildi: 10_munih-isar-348_jpg.rf.dabc7066d10134952467738077e4a7d9
# [20:32:26] 📂 VEHICLE - Marseille - Kaydedildi: 01_marsilya-506_jpg.rf.97f5eb690e28f7464e2a1e87f1c3e8d7
# [20:32:26] 📂 VEHICLE - Marseille - Kaydedildi: 02_marsilya-500_jpg.rf.2467201ec081c98a746c6e58aa3c6b2e
# [20:32:26] 📂 VEHICLE - Marseille - Kaydedildi: 03_marsilya-522_jpg.rf.4bce3d906fda9619d4ea0a3b446b28af
# [20:32:26] 📂 VEHICLE - Marseille - Kaydedildi: 04_marsilya2-409_jpg.rf.18ddf7967c51513f7181b15a46facdeb
# [20:32:26] 📂 VEHICLE - Marseille - Kaydedildi: 05_marsilya2-648_jpg.rf.a3a1ba676fa9897bed796604b9045708
# [20:32:26] 📂 VEHICLE - Marseille - Kaydedildi: 06_marsilya2-233_jpg.rf.e96643bc3de79c9e490005c04d7b3a68
# [20:32:26] 📂 VEHICLE - Marseille - Kaydedildi: 07_marsilya-269_jpg.rf.5a937c542bfdf970a7dc80a8671d4e24
# [20:32:26] 📂 VEHICLE - Marseille - Kaydedildi: 08_marsilya-717_jpg.rf.57982131ae62385a9a8b01002de767cb
# [20:32:26] 📂 VEHICLE - Marseille - Kaydedildi: 09_marsilya-671_jpg.rf.ae764ef2a579bb4029235ca7f36885ea
# [20:32:26] 📂 VEHICLE - Marseille - Kaydedildi: 10_marsilya2-678_jpg.rf.8fdc797b5e84adf421ef42a59b502a9f
# [20:32:26] 📂 VEHICLE - Unknown - Kaydedildi: 01_Street-View-360_jpg.rf.b60e5ea133d76f00474a0da3fe9fcb9d
# [20:32:26] ✅ VEHICLE tamamlandı (18.7 saniye)

# %%
import cv2
import time
from pathlib import Path
from datetime import datetime
from concurrent.futures import ThreadPoolExecutor
from PIL import Image

# === AYARLAR ===
labels_dir = Path('runs/detect/yolov10-txtresults/labels')
gt_dir = Path('/truba/home/baakgul/roadtr-14032025/test/labels')
images_dir = Path('/truba/home/baakgul/roadtr-14032025/test/images')
output_dir = Path('yolov10-best-10-separated-final-300dpi')  # GÜNCELLENDİ
output_dir.mkdir(parents=True, exist_ok=True)

iou_threshold = 0.5
class_names = ['pedestrian', 'road', 'vehicle']
class_ids = {'pedestrian': 0, 'road': 1, 'vehicle': 2}
colors = {
    'gt': (0, 255, 0),
    0: (0, 255, 255),
    1: (0, 0, 0),
    2: (0, 0, 255)
}

city_keywords = {
    'istanbul': ['libadiye', 'levent', 'taksim', 'ciragan', 'barbaros', 'dolmabahce', 'bagdat', 'muallim', 'katar'],
    'paris': ['paris-champs'],
    'munih': ['munih'],
    'marsilya': ['marsilya']
}

city_translation = {
    'istanbul': 'Istanbul',
    'paris': 'Paris',
    'munih': 'Munich',
    'marsilya': 'Marseille',
    'unknown': 'Unknown'
}

def now(): return datetime.now().strftime('%H:%M:%S')

def calculate_iou(boxA, boxB):
    xA, yA, wA, hA = boxA
    xa1, ya1, xa2, ya2 = xA - wA / 2, yA - hA / 2, xA + wA / 2, yA + hA / 2
    xB, yB, wB, hB = boxB
    xb1, yb1, xb2, yb2 = xB - wB / 2, yB - hB / 2, xB + wB / 2, yB + hB / 2

    inter_x1 = max(xa1, xb1)
    inter_y1 = max(ya1, yb1)
    inter_x2 = min(xa2, xb2)
    inter_y2 = min(ya2, yb2)
    inter_area = max(0, inter_x2 - inter_x1) * max(0, inter_y2 - inter_y1)
    area_a = (xa2 - xa1) * (ya2 - ya1)
    area_b = (xb2 - xb1) * (yb2 - yb1)
    return inter_area / (area_a + area_b - inter_area + 1e-6)

def draw_single_class_boxes(image, boxes, classes, cls_id, color_override=None, is_gt=False):
    h, w = image.shape[:2]
    for cls, box in zip(classes, boxes):
        if cls != cls_id:
            continue
        x_c, y_c, bw, bh = box
        x1 = int((x_c - bw / 2) * w)
        y1 = int((y_c - bh / 2) * h)
        x2 = int((x_c + bw / 2) * w)
        y2 = int((y_c + bh / 2) * h)

        color = color_override if color_override else colors[cls]
        thickness = 2 if cls_id == 1 else 1
        cv2.rectangle(image, (x1, y1), (x2, y2), color, thickness)
    return image

def check_overlap(new_box, existing_boxes):
    x1, y1, x2, y2 = new_box
    for ex in existing_boxes:
        ex1, ey1, ex2, ey2 = ex
        if not (x2 < ex1 or x1 > ex2 or y2 < ey1 or y1 > ey2):
            return True
    return False

def get_city_from_name(name):
    for city, keywords in city_keywords.items():
        if any(keyword in name for keyword in keywords):
            return city
    return 'unknown'

def save_with_dpi(img_array, path, dpi=(300, 300)):
    img_rgb = cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB)
    img_pil = Image.fromarray(img_rgb)
    img_pil.save(path, dpi=dpi, quality=95)

def process_file_for_class(cls_name):
    start = time.time()
    cls_id = class_ids[cls_name]
    results_by_city = {city: [] for city in city_keywords}
    results_by_city['unknown'] = []
    txt_files = list(labels_dir.glob("*.txt"))

    print(f"[{now()}] 🚀 Başlıyor: {cls_name.upper()}")

    for txt_file in txt_files:
        image_stem = txt_file.stem
        image_file = images_dir / f"{image_stem}.jpg"
        if not image_file.exists():
            continue

        img = cv2.imread(str(image_file))
        if img is None:
            continue

        gt_path = gt_dir / txt_file.name
        if not gt_path.exists():
            continue

        with open(gt_path) as f:
            gt_lines = [line.strip().split() for line in f if line.strip()]
        gt_classes = [int(l[0]) for l in gt_lines]
        gt_boxes = [list(map(float, l[1:5])) for l in gt_lines]

        with open(txt_file) as f:
            det_lines = [line.strip().split() for line in f if line.strip()]
        det_classes = [int(l[0]) for l in det_lines]
        det_boxes = [list(map(float, l[1:5])) for l in det_lines]

        filtered_det_boxes = []
        filtered_det_classes = []
        matched_gt = set()

        for i, gt_box in enumerate(gt_boxes):
            if gt_classes[i] != cls_id:
                continue
            for j, det_box in enumerate(det_boxes):
                if det_classes[j] != cls_id:
                    continue
                if calculate_iou(gt_box, det_box) >= iou_threshold:
                    filtered_det_boxes.append(det_box)
                    filtered_det_classes.append(cls_id)
                    matched_gt.add(i)
                    break

        match_count = len(matched_gt)
        if match_count > 0:
            city = get_city_from_name(image_stem)
            results_by_city[city].append({
                "match": match_count,
                "image": img,
                "gt_boxes": gt_boxes,
                "gt_classes": gt_classes,
                "det_boxes": filtered_det_boxes,
                "det_classes": filtered_det_classes,
                "name": txt_file.stem
            })

    for city, results in results_by_city.items():
        city_label = city_translation.get(city, city.capitalize())
        city_output = output_dir / cls_name / city_label
        city_output.mkdir(parents=True, exist_ok=True)

        top10 = sorted(results, key=lambda x: x["match"], reverse=True)[:10]

        for i, result in enumerate(top10, 1):
            base_name = f"{i:02d}_{result['name']}"
            single_output = city_output / base_name
            single_output.mkdir(parents=True, exist_ok=True)

            ori_img = result["image"]
            gt_img = draw_single_class_boxes(
                ori_img.copy(), result["gt_boxes"], result["gt_classes"],
                cls_id, color_override=colors['gt'])

            det_img = draw_single_class_boxes(
                ori_img.copy(), result["det_boxes"], result["det_classes"],
                cls_id, color_override=colors[cls_id])

            h, w = ori_img.shape[:2]
            zoom_overlay = det_img.copy()
            max_zoom_size = 96
            zoom_positions = []

            for box in result["det_boxes"]:
                x_c, y_c, bw, bh = box
                box_w = int(bw * w)
                box_h = int(bh * h)
                if box_w >= 32 or box_h >= 32:
                    continue

                x1 = max(0, int((x_c - bw / 2) * w))
                y1 = max(0, int((y_c - bh / 2) * h))
                x2 = min(w, int((x_c + bw / 2) * w))
                y2 = min(h, int((y_c + bh / 2) * h))
                crop = ori_img[y1:y2, x1:x2]
                if crop.size <= 0:
                    continue

                zoom_factor = min(max_zoom_size // max(box_w, box_h), 4)
                zoom_w, zoom_h = box_w * zoom_factor, box_h * zoom_factor
                resized = cv2.resize(crop, (zoom_w, zoom_h), interpolation=cv2.INTER_LINEAR)
                cv2.rectangle(resized, (0, 0), (zoom_w - 1, zoom_h - 1), colors[cls_id], 2)

                paste_x, paste_y = x1, y1 - zoom_h - 10
                while check_overlap((paste_x, paste_y, paste_x + zoom_w, paste_y + zoom_h), zoom_positions):
                    paste_y -= 5
                    if paste_y < 0:
                        paste_y = y2 + 10
                    if paste_y + zoom_h > h:
                        break

                if paste_y + zoom_h > h or paste_x + zoom_w > w:
                    continue

                zoom_positions.append((paste_x, paste_y, paste_x + zoom_w, paste_y + zoom_h))
                zoom_overlay[paste_y:paste_y+zoom_h, paste_x:paste_x+zoom_w] = resized

                arrow_start = (x1 + box_w // 2, y1)
                arrow_end = (paste_x + zoom_w // 2, paste_y + zoom_h - 1)
                cv2.arrowedLine(zoom_overlay, arrow_start, arrow_end, (255, 0, 255), 1, tipLength=0.2)

            save_with_dpi(ori_img, single_output / "original.jpg")
            save_with_dpi(gt_img, single_output / "labels.jpg")
            save_with_dpi(zoom_overlay, single_output / "detections.jpg")

            print(f"[{now()}] 📂 {cls_name.upper()} - {city_label} - Kaydedildi: {base_name}")

    print(f"[{now()}] ✅ {cls_name.upper()} tamamlandı ({time.time()-start:.1f} saniye)")

# === Paralel çalıştır ===
with ThreadPoolExecutor(max_workers=3) as executor:
    executor.map(process_file_for_class, class_names)
# Out:
# [01:23:15] 🚀 Başlıyor: PEDESTRIAN
# [01:23:15] 🚀 Başlıyor: VEHICLE
# [01:23:15] 🚀 Başlıyor: ROAD
# [01:23:50] 📂 ROAD - Istanbul - Kaydedildi: 01_katar-482_jpg.rf.a2522fa55e30b6b22de87cdd7b30df63
# [01:23:50] 📂 ROAD - Istanbul - Kaydedildi: 02_bagdat-1-293_jpg.rf.74450bad7504458a2a6298c5ec855fd1
# [01:23:50] 📂 ROAD - Istanbul - Kaydedildi: 03_bagdat-1-4_jpg.rf.665736ea603fff5ddba9e99f9fb4ecf7
# [01:23:50] 📂 PEDESTRIAN - Istanbul - Kaydedildi: 01_bagdat-1-382_jpg.rf.4ae73d9941bdea605dc2dbd0280ed888
# [01:23:50] 📂 ROAD - Istanbul - Kaydedildi: 04_muallimnaci-284_jpg.rf.dd3b9eca3aaf5054e147bd82721f6121
# [01:23:50] 📂 PEDESTRIAN - Istanbul - Kaydedildi: 02_bagdat-1-422_jpg.rf.7e3ee5b10b2373426f0701098ce3a18e
# [01:23:51] 📂 ROAD - Istanbul - Kaydedildi: 05_ciragan-108_jpg.rf.2e2117ac297317c91a05682123abc5a0
# [01:23:51] 📂 PEDESTRIAN - Istanbul - Kaydedildi: 03_bagdat-1-381_jpg.rf.4ff3273da5bf43f5739f9de23572004d
# [01:23:51] 📂 ROAD - Istanbul - Kaydedildi: 06_katar-1104_jpg.rf.35de596930f413624c5a3d3038216dfb
# [01:23:51] 📂 VEHICLE - Istanbul - Kaydedildi: 01_bagdat-1-443_jpg.rf.a32fec5e0045057885589929a50dbba6
# [01:23:51] 📂 PEDESTRIAN - Istanbul - Kaydedildi: 04_bagdat-1-257_jpg.rf.74ab909f0e2a8232f83b52696f2a6bd3
# [01:23:51] 📂 VEHICLE - Istanbul - Kaydedildi: 02_levent-52_jpg.rf.74be640901ea9600c80d30451de87d3e
# [01:23:51] 📂 ROAD - Istanbul - Kaydedildi: 07_bagdat-1-440_jpg.rf.516a2201d690aecaf570b43655d14236
# [01:23:51] 📂 PEDESTRIAN - Istanbul - Kaydedildi: 05_bagdat-1-69_jpg.rf.91b5407f9882d6c58729555b404d8612
# [01:23:51] 📂 VEHICLE - Istanbul - Kaydedildi: 03_bagdat-1-400_jpg.rf.6bfb079a34865f249ab51400f5aa068b
# [01:23:51] 📂 ROAD - Istanbul - Kaydedildi: 08_katar-687_jpg.rf.8f48c9a40d7c10a6a4a9df01fceef9f1
# [01:23:51] 📂 VEHICLE - Istanbul - Kaydedildi: 04_bagdat-1-365_jpg.rf.96d2bb464a27dae6bd1d0b2a27efe6db
# [01:23:51] 📂 PEDESTRIAN - Istanbul - Kaydedildi: 06_bagdat-1-358_jpg.rf.e2d263ed5a9d12d667d2329a3bc2a3bf
# [01:23:51] 📂 ROAD - Istanbul - Kaydedildi: 09_bagdat-1-33_jpg.rf.f392b45498cb8d4e7029ff5a369bc88e
# [01:23:51] 📂 ROAD - Istanbul - Kaydedildi: 10_bagdat-1-339_jpg.rf.edbfbc08b14a9da7a051755d07f10040
# [01:23:51] 📂 VEHICLE - Istanbul - Kaydedildi: 05_bagdat-1-417_jpg.rf.5a5bdd5ae05d22998aa484017a56998b
# [01:23:51] 📂 PEDESTRIAN - Istanbul - Kaydedildi: 07_bagdat-1-286_jpg.rf.cf6c6ea0eee710e5596cc8fc6dce2010
# [01:23:51] 📂 ROAD - Paris - Kaydedildi: 01_paris-champs-426_jpg.rf.c33211b6cd4bf7dd6e8ba9a0d705b948
# [01:23:51] 📂 PEDESTRIAN - Istanbul - Kaydedildi: 08_bagdat-1-417_jpg.rf.5a5bdd5ae05d22998aa484017a56998b
# [01:23:51] 📂 VEHICLE - Istanbul - Kaydedildi: 06_bagdat-1-416_jpg.rf.953f32e3c9e9dad6e0156a4902041d91
# [01:23:51] 📂 PEDESTRIAN - Istanbul - Kaydedildi: 09_bagdat-1-428_jpg.rf.8864fccf3ace5331fac031240ebd05a4
# [01:23:51] 📂 ROAD - Paris - Kaydedildi: 02_paris-champs-1122_jpg.rf.3e360dd045d304f26e4d18aa7f07ae75
# [01:23:51] 📂 VEHICLE - Istanbul - Kaydedildi: 07_bagdat-1-58_jpg.rf.91d6fc1b615eaffe9ff69cfa6b390301
# [01:23:51] 📂 ROAD - Paris - Kaydedildi: 03_paris-champs-1299_jpg.rf.ced4137cfa0ecdb8e74d80a9ee3511da
# [01:23:51] 📂 PEDESTRIAN - Istanbul - Kaydedildi: 10_bagdat-1-284_jpg.rf.d7eb1e1c7bcb4d7df567451003c12e5f
# [01:23:51] 📂 VEHICLE - Istanbul - Kaydedildi: 08_libadiye-185_jpg.rf.ea0ccbeb7d763558be43ba4004bc15bb
# [01:23:52] 📂 ROAD - Paris - Kaydedildi: 04_paris-champs-888_jpg.rf.bfc4b6d2585392c1984cbfa1be86d322
# [01:23:52] 📂 PEDESTRIAN - Paris - Kaydedildi: 01_paris-champs-500_jpg.rf.b12f50457c414318a6d187fddc01838e
# [01:23:52] 📂 VEHICLE - Istanbul - Kaydedildi: 09_bagdat-1-397_jpg.rf.20ba061b839462b53b21b971f74c8bb6
# [01:23:52] 📂 PEDESTRIAN - Paris - Kaydedildi: 02_paris-champs-381_jpg.rf.69281cab69342252b0646b60c7d78e68
# [01:23:52] 📂 ROAD - Paris - Kaydedildi: 05_paris-champs-1408_jpg.rf.88db03540d3eadd8b02480ed39b81998
# [01:23:52] 📂 VEHICLE - Istanbul - Kaydedildi: 10_bagdat-1-445_jpg.rf.1aefef7d483b648ded0f2b9881d58d5b
# [01:23:52] 📂 PEDESTRIAN - Paris - Kaydedildi: 03_paris-champs-426_jpg.rf.c33211b6cd4bf7dd6e8ba9a0d705b948
# [01:23:52] 📂 ROAD - Paris - Kaydedildi: 06_paris-champs-1118_jpg.rf.ff324160d1eb8b8ab396ed7a1f62a4d4
# [01:23:52] 📂 VEHICLE - Paris - Kaydedildi: 01_paris-champs-1009_jpg.rf.87b9a7ce2dd31bbde28d2be7ccb0b8fc
# [01:23:52] 📂 ROAD - Paris - Kaydedildi: 07_paris-champs-313_jpg.rf.83d503408cba968433dc2e62dbd0512b
# [01:23:52] 📂 PEDESTRIAN - Paris - Kaydedildi: 04_paris-champs-888_jpg.rf.bfc4b6d2585392c1984cbfa1be86d322
# [01:23:52] 📂 ROAD - Paris - Kaydedildi: 08_paris-champs-1092_jpg.rf.b1787da04ff9cf962ce14519227e7c28
# [01:23:52] 📂 VEHICLE - Paris - Kaydedildi: 02_paris-champs-426_jpg.rf.c33211b6cd4bf7dd6e8ba9a0d705b948
# [01:23:52] 📂 PEDESTRIAN - Paris - Kaydedildi: 05_paris-champs-1408_jpg.rf.88db03540d3eadd8b02480ed39b81998
# [01:23:52] 📂 ROAD - Paris - Kaydedildi: 09_paris-champs-557_jpg.rf.9dce136a6c1983c905989ba78dcfeb11
# [01:23:52] 📂 PEDESTRIAN - Paris - Kaydedildi: 06_paris-champs-107_jpg.rf.a8bb897342650dc4f8f6b4af342c393d
# [01:23:52] 📂 VEHICLE - Paris - Kaydedildi: 03_paris-champs-500_jpg.rf.b12f50457c414318a6d187fddc01838e
# [01:23:52] 📂 ROAD - Paris - Kaydedildi: 10_paris-champs-1268_jpg.rf.92ec4154015834e57f1a3df997ac6583
# [01:23:52] 📂 VEHICLE - Paris - Kaydedildi: 04_paris-champs-845_jpg.rf.cafa10b66cecfcd08749b0bd83d9be30
# [01:23:52] 📂 PEDESTRIAN - Paris - Kaydedildi: 07_paris-champs-557_jpg.rf.9dce136a6c1983c905989ba78dcfeb11
# [01:23:52] 📂 ROAD - Munich - Kaydedildi: 01_munih-einstein-1316_jpg.rf.115a01d93019556e39ce341f7ae68242
# [01:23:52] 📂 VEHICLE - Paris - Kaydedildi: 05_paris-champs-143_jpg.rf.4502fa52d0418c25f1f7dcd469ab6a1e
# [01:23:53] 📂 PEDESTRIAN - Paris - Kaydedildi: 08_paris-champs-511_jpg.rf.0f0aa065787a5a088c32c7a309706561
# [01:23:53] 📂 ROAD - Munich - Kaydedildi: 02_munih-einstein-1781_jpg.rf.28e8c02be93319a73a39880218936cc9
# [01:23:53] 📂 VEHICLE - Paris - Kaydedildi: 06_paris-champs-1122_jpg.rf.3e360dd045d304f26e4d18aa7f07ae75
# [01:23:53] 📂 PEDESTRIAN - Paris - Kaydedildi: 09_paris-champs-265_jpg.rf.640ac4c9e4df43c9a3cc168528696ba6
# [01:23:53] 📂 VEHICLE - Paris - Kaydedildi: 07_paris-champs-996_jpg.rf.1494614d996dc3261dcb900d3fbeb74f
# [01:23:53] 📂 ROAD - Munich - Kaydedildi: 03_munih-einstein-1460_jpg.rf.c88adc5c3b9417d71615b00e8c2d3f78
# [01:23:53] 📂 VEHICLE - Paris - Kaydedildi: 08_paris-champs-762_jpg.rf.e6bd8f9466999ea4bb4ab9cbb02cba59
# [01:23:53] 📂 PEDESTRIAN - Paris - Kaydedildi: 10_paris-champs-641_jpg.rf.780f6398d783ea2f1f70fff804575816
# [01:23:53] 📂 ROAD - Munich - Kaydedildi: 04_munih-einstein-1025_jpg.rf.1b1dd53e82b0ac3d9996e6a232eec1d5
# [01:23:53] 📂 VEHICLE - Paris - Kaydedildi: 09_paris-champs-381_jpg.rf.69281cab69342252b0646b60c7d78e68
# [01:23:53] 📂 PEDESTRIAN - Munich - Kaydedildi: 01_munih-leopold-197_jpg.rf.bc55c495695b610fde9f395d54851fe0
# [01:23:53] 📂 ROAD - Munich - Kaydedildi: 05_munih-einstein-1291_jpg.rf.b09dcf58e954a102f8289727e484773d
# [01:23:53] 📂 VEHICLE - Paris - Kaydedildi: 10_paris-champs-1003_jpg.rf.b026a31aed06c09ac0fba40847f266b0
# [01:23:53] 📂 PEDESTRIAN - Munich - Kaydedildi: 02_munih-leopold-55_jpg.rf.1a8e3d85011c92265890bde0b67b4c59
# [01:23:53] 📂 VEHICLE - Munich - Kaydedildi: 01_munih-einstein-881_jpg.rf.7bdfcfd46d38ae0286a268087c46ba1f
# [01:23:53] 📂 ROAD - Munich - Kaydedildi: 06_munih-einstein-469_jpg.rf.e1c783b52646e69130be882045d4758e
# [01:23:53] 📂 PEDESTRIAN - Munich - Kaydedildi: 03_munih-leopold-198_jpg.rf.1bf5a494da6ceaab68d5d83b8453afcb
# [01:23:53] 📂 VEHICLE - Munich - Kaydedildi: 02_munih-einstein-1199_jpg.rf.8f84f261b4b6632a1b8ff31671aa7047
# [01:23:53] 📂 ROAD - Munich - Kaydedildi: 07_munih-einstein-1658_jpg.rf.d29b7cfbd12ac625183dda815a12dc76
# [01:23:53] 📂 PEDESTRIAN - Munich - Kaydedildi: 04_munih-einstein-338_jpg.rf.c86d416ef5a240ec5f2dbacf1c6bd2f4
# [01:23:53] 📂 VEHICLE - Munich - Kaydedildi: 03_munih-einstein-514_jpg.rf.7459b39e2dc047ee6298a3041e9f31c1
# [01:23:54] 📂 ROAD - Munich - Kaydedildi: 08_munih-einstein-802_jpg.rf.99b072a3707e24693c47cd4b9a7a477e
# [01:23:54] 📂 PEDESTRIAN - Munich - Kaydedildi: 05_munih-leopold-227_jpg.rf.b2144dd9f51a61be78e5db912b29c494
# [01:23:54] 📂 VEHICLE - Munich - Kaydedildi: 04_munih-leopold-464_jpg.rf.7940bb961b5fecfd457ce33c9d0281d3
# [01:23:54] 📂 ROAD - Munich - Kaydedildi: 09_munih-einstein-1050_jpg.rf.984c4a2228b24c2cb0d4971033f3c0ee
# [01:23:54] 📂 PEDESTRIAN - Munich - Kaydedildi: 06_munih-leopold-418_jpg.rf.5cd21cf73783db3a0afc857f776b5bcb
# [01:23:54] 📂 ROAD - Munich - Kaydedildi: 10_munih-einstein-54_jpg.rf.65f852b5ef66dbba79f71ffa87252763
# [01:23:54] 📂 PEDESTRIAN - Munich - Kaydedildi: 07_munih-leopold-236_jpg.rf.17594dc5100b3483283f98726309ba12
# [01:23:54] 📂 VEHICLE - Munich - Kaydedildi: 05_munih-einstein-885_jpg.rf.dbb4a7248ce7717d803fb034ca9bc29d
# [01:23:54] 📂 ROAD - Marseille - Kaydedildi: 01_marsilya2-562_jpg.rf.79e79e5f1892304717ffe9980efb0816
# [01:23:54] 📂 VEHICLE - Munich - Kaydedildi: 06_munih-leopold-520_jpg.rf.7cf633275796cd2c22f475693ee7ac9a
# [01:23:54] 📂 ROAD - Marseille - Kaydedildi: 02_marsilya-541_jpg.rf.3375977da647914e40879a06e636f1d6
# [01:23:54] 📂 PEDESTRIAN - Munich - Kaydedildi: 08_munih-einstein-332_jpg.rf.c1b2c0f7ba0dfbc8483c1a86660bee40
# [01:23:54] 📂 VEHICLE - Munich - Kaydedildi: 07_munih-leopold-543_jpg.rf.c0c6a74a50ecf65b74007fb8886fdddb
# [01:23:54] 📂 ROAD - Marseille - Kaydedildi: 03_marsilya-717_jpg.rf.57982131ae62385a9a8b01002de767cb
# [01:23:54] 📂 VEHICLE - Munich - Kaydedildi: 08_munih-leopold-494_jpg.rf.bdfa274268304e2ad5003e4f1becb910
# [01:23:54] 📂 PEDESTRIAN - Munich - Kaydedildi: 09_munih-leopold-133_jpg.rf.ac63b1501299c1361a7e218d6447ff12
# [01:23:54] 📂 ROAD - Marseille - Kaydedildi: 04_marsilya-1585_jpg.rf.0169b38e08bfb773908d06c0e6a1c348
# [01:23:54] 📂 PEDESTRIAN - Munich - Kaydedildi: 10_munih-leopold-228_jpg.rf.8f2bd0d921b59aa3081c33027946f277
# [01:23:54] 📂 VEHICLE - Munich - Kaydedildi: 09_munih-einstein-475_jpg.rf.3be591ce92ed27c0c79259595a03a2e2
# [01:23:54] 📂 ROAD - Marseille - Kaydedildi: 05_marsilya-1062_jpg.rf.4270419462d5c520c12f345645803909
# [01:23:54] 📂 VEHICLE - Munich - Kaydedildi: 10_munih-isar-348_jpg.rf.dabc7066d10134952467738077e4a7d9
# [01:23:54] 📂 PEDESTRIAN - Marseille - Kaydedildi: 01_marsilya-531_jpg.rf.6086959c55d5f7cefdd5f6120aa39aee
# [01:23:54] 📂 ROAD - Marseille - Kaydedildi: 06_marsilya2-561_jpg.rf.177370c6ed4092bf98ebb829610f5e34
# [01:23:55] 📂 ROAD - Marseille - Kaydedildi: 07_marsilya-1814_jpg.rf.2157db3df9c8110a7989a914925f2a76[01:23:55] 📂 PEDESTRIAN - Marseille - Kaydedildi: 02_marsilya-530_jpg.rf.62c230e571b467c84f5f4d1724ff2999
#
# [01:23:55] 📂 VEHICLE - Marseille - Kaydedildi: 01_marsilya-506_jpg.rf.97f5eb690e28f7464e2a1e87f1c3e8d7
# [01:23:55] 📂 ROAD - Marseille - Kaydedildi: 08_marsilya-1605_jpg.rf.81f341246b611b47e777232d7616f6d0
# [01:23:55] 📂 PEDESTRIAN - Marseille - Kaydedildi: 03_marsilya-470_jpg.rf.194ac3cb5e08a4aae4847fd4b86dfa15
# [01:23:55] 📂 VEHICLE - Marseille - Kaydedildi: 02_marsilya-500_jpg.rf.2467201ec081c98a746c6e58aa3c6b2e
# [01:23:55] 📂 ROAD - Marseille - Kaydedildi: 09_marsilya2-355_jpg.rf.1d09d220f8870fb1b7d9e0c93a75da4a
# [01:23:55] 📂 PEDESTRIAN - Marseille - Kaydedildi: 04_marsilya-542_jpg.rf.97a64ca58d3441817998dfdee2694b09
# [01:23:55] 📂 VEHICLE - Marseille - Kaydedildi: 03_marsilya-522_jpg.rf.4bce3d906fda9619d4ea0a3b446b28af
# [01:23:55] 📂 ROAD - Marseille - Kaydedildi: 10_marsilya2-693_jpg.rf.5881dcc349e13f3697797c63441523b2
# [01:23:55] 📂 ROAD - Unknown - Kaydedildi: 01_Street-View-360_jpg.rf.b60e5ea133d76f00474a0da3fe9fcb9d
# [01:23:55] ✅ ROAD tamamlandı (40.6 saniye)
# [01:23:55] 📂 PEDESTRIAN - Marseille - Kaydedildi: 05_marsilya-632_jpg.rf.d3d0aaf61ecb528284c37f3a521b79dd
# [01:23:55] 📂 VEHICLE - Marseille - Kaydedildi: 04_marsilya2-409_jpg.rf.18ddf7967c51513f7181b15a46facdeb
# [01:23:55] 📂 PEDESTRIAN - Marseille - Kaydedildi: 06_marsilya-464_jpg.rf.8c8153f120ea16f8947489a0362330a3
# [01:23:55] 📂 VEHICLE - Marseille - Kaydedildi: 05_marsilya2-648_jpg.rf.a3a1ba676fa9897bed796604b9045708
# [01:23:55] 📂 PEDESTRIAN - Marseille - Kaydedildi: 07_marsilya-362_jpg.rf.03b525c04c61794a0c38df2321fa1bc5
# [01:23:55] 📂 VEHICLE - Marseille - Kaydedildi: 06_marsilya2-233_jpg.rf.e96643bc3de79c9e490005c04d7b3a68
# [01:23:56] 📂 VEHICLE - Marseille - Kaydedildi: 07_marsilya-269_jpg.rf.5a937c542bfdf970a7dc80a8671d4e24
# [01:23:56] 📂 PEDESTRIAN - Marseille - Kaydedildi: 08_marsilya-529_jpg.rf.e3d654f4eff17abe14edefd946b9c6db
# [01:23:56] 📂 VEHICLE - Marseille - Kaydedildi: 08_marsilya-717_jpg.rf.57982131ae62385a9a8b01002de767cb
# [01:23:56] 📂 PEDESTRIAN - Marseille - Kaydedildi: 09_marsilya-577_jpg.rf.ad9163a55eeee73b76126a3d4ccdc0cb
# [01:23:56] 📂 PEDESTRIAN - Marseille - Kaydedildi: 10_marsilya-674_jpg.rf.32f5fd36c637b4fc6e5ea911a8cb78c8
# [01:23:56] 📂 VEHICLE - Marseille - Kaydedildi: 09_marsilya-671_jpg.rf.ae764ef2a579bb4029235ca7f36885ea
# [01:23:56] 📂 PEDESTRIAN - Unknown - Kaydedildi: 01_Street-View-360_jpg.rf.b60e5ea133d76f00474a0da3fe9fcb9d
# [01:23:56] ✅ PEDESTRIAN tamamlandı (41.5 saniye)
# [01:23:56] 📂 VEHICLE - Marseille - Kaydedildi: 10_marsilya2-678_jpg.rf.8fdc797b5e84adf421ef42a59b502a9f
# [01:23:56] 📂 VEHICLE - Unknown - Kaydedildi: 01_Street-View-360_jpg.rf.b60e5ea133d76f00474a0da3fe9fcb9d
# [01:23:56] ✅ VEHICLE tamamlandı (41.6 saniye)
